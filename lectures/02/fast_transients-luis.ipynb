# %% [markdown]
# # Fast Transient Searches
#
# Author: Igor Andreoni <br>
# Contact: andreoni@umd.edu <br>
# ZTF Summer School 2022

# %% [markdown]
# ### Objective
# The objective of this notebook is to learn how to mine a large dataset for (rare) extragalactic fast transient sources.
#
# ### Introduction
# Wide-field surveys like the Zwicky Transient Facility (ZTF) image the entire observable sky almost every night multiple times. This makes ZTF as excellent instrument for time-domain astronomy. Image subtraction between a new "science" image and a deep "reference" (or "template") image makes every new source, or every source that changes in luminosity, stand out. When such a source is identified in a new image, an alert packet is issued, which is a dictionary rich with information, including differential photometry between the science and the template images.
#
# ZTF issues about 300,000 alerts every night. Searching for extragalactic fast transients constitutes a "needle in the haystack" big data challenge.
#
# ### Method
# A data set (see below) is provided which is very similar to the stream of alerts that ZTF issues in one night. The amount of alerts is in the order of ~100k, which is a number large enough to make it unsustainable for a human to check each source individually on a daily basis. The objective of the notebook is to apply a number of well-motivated cuts to bring an overwhelming amount of information down to a manageable number of transients that astronomers can vet. The main steps will be:
# - read and understand the data
# - plot light curves
# - apply cuts progressively
# - when < 10 candidates are left, inspect them in detail
#
#
# ### The data set
# Two data files were prepared for this school activity, both in JSON format. JSON files are, essentially, dictionaries.
#
# The alerts were all issued on the night of 2021-02-05 UT. The total number of alerts issued on that night approximated 1 million. If all the alerts were to be used, complete with all their entries, they total disk space for the 2021-02-05 night is larger than 16GB. To facilitate the download and handling of the data, alerts were selected that:
# - have at least 2 detections for the source (ndethist >= 2)
# - are likely real according to two real/bogus classifiers (drb > 0.8; braai > 0.8)
# - left a positive residual after image subtraction, i.e. the flux in the science image is larger than in the template image (warning: the source might have been fainter than the template in a past science image, generating a "negative" subtraction!)
#
# The data files are `data/fast_transient_alerts.json` for the alerts, `data/fast_transient_lc.json` for the light curves.
#
# - `data/fast_transient_alerts.json` Uniform JSON file (readable as a table using `pandas`) containing a selection of relevant information from the original alerts.
# - `data/fast_transient_lc.json` Light curves. The light curve of some transients have thousands of data points. To keep the data set manageable and our eyes on the scientific objective to discover fast transients, some the light curves were cut. In particular, **empty light curves** were assigned to those transients that:
#     - have at least one "negative" subtraction in the past (see above)
#     - are located at Galactic latitude `-8 deg < b < +8 deg` <br>
# In addition, only those data points within the last 30 days before the alert was issued are present in the light curves. Long-duration transients, variables, and repeatingly bursting sources are outside the scope of this activity. However, data points acquired after the last alert included in the `fast_transient_alerts.json` file will be present.
#
# ### Requirements
# * python 3
# * numpy, pandas, matplotlib, astropy, collections
#
# ### Useful links
# [ZTF Avro schema for the alerts](https://zwickytransientfacility.github.io/ztf-avro-alert/schema.html)<br>
# [Public ZTF alerts](https://ztf.uw.edu/alerts/public/)<br>
# [Alert brokers for ZTF and Rubin Observatory](https://www.lsst.org/scientists/alert-brokers)

# %% [markdown]
# ## Import python packages

# %%
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import OrderedDict

# %% [markdown]
# ## Read and understand the data

# %% [markdown]
# Read the data file. Beware that this action could take several minutes. The alerts JSON file is uniform and can be read as a `pandas` data frame.

# %%
# Open the file with the alerts
alerts_filename = "data/fast_transient_alerts.json"
df_alerts = pd.read_json(alerts_filename)
# To have one alert per row instead of column, use transpose()
df_alerts = df_alerts.transpose()

# %%
df_alerts
# Out:
#                                       jd fid isdiffpos rcid          ra  \
# 601cb75947230767c903ce48  2459250.626065   1         t   45   41.706031
# 601cb758040c9a45b915243b  2459250.626065   1         t   52    46.59873
# 601cb761da8192014092f81a  2459250.626065   1         t    4    46.82753
# 601cb75284abedb0473956ad  2459250.626065   1         t   27   44.834644
# 601cb758da8192014092f80d  2459250.626065   1         t   52    46.82591
# ...                                  ...  ..       ...  ...         ...
# 601d27da84abedb04739f084  2459250.958634   1         t   24  163.434033
# 601d27ac040c9a45b915babc  2459250.958634   1         t   31  161.765062
# 601d27d3da81920140939031  2459250.958634   1         t   19  168.773193
# 601d27d1739b2bb2412ca39b  2459250.958634   1         t    7  166.154602
# 601d27ca040c9a45b915bac7  2459250.958634   1         t   14  159.981289
#
#                                 dec     magpsf  sigmapsf        rb ssdistnr  \
# 601cb75947230767c903ce48 -22.509571  15.914849  0.052548  0.512857   -999.0
# 601cb758040c9a45b915243b -20.729952  19.315357  0.187526  0.528571   -999.0
# 601cb761da8192014092f81a -27.066677  19.544296  0.215844  0.545714   -999.0
# 601cb75284abedb0473956ad -25.714721  19.561789  0.213745      0.56   -999.0
# 601cb758da8192014092f80d -20.531972  18.419357  0.183404  0.595714   -999.0
# ...                             ...        ...       ...       ...      ...
# 601d27da84abedb04739f084  43.836402  18.297316  0.069884  0.978571      0.0
# 601d27ac040c9a45b915babc  42.716231  18.129463  0.073452      0.98   -999.0
# 601d27d3da81920140939031  42.992601  18.081432  0.065831  0.984286      0.0
# 601d27d1739b2bb2412ca39b  40.622032  19.469931  0.131736  0.984286   -999.0
# 601d27ca040c9a45b915bac7  40.987857  19.727247  0.168976  0.987143   -999.0
#
#                           ...     jdstarthist       jdendhist     srmag2  \
# 601cb75947230767c903ce48  ...  2458383.932454  2459250.626065    18.7122
# 601cb758040c9a45b915243b  ...  2458860.605127  2459250.626065    21.7882
# 601cb761da8192014092f81a  ...  2459117.897257  2459250.626065    20.7647
# 601cb75284abedb0473956ad  ...  2458423.900556  2459250.626065    21.4858
# 601cb758da8192014092f80d  ...  2458427.813866  2459250.626065    20.7204
# ...                       ...             ...             ...        ...
# 601d27da84abedb04739f084  ...  2459250.958171  2459250.958634  21.620899
# 601d27ac040c9a45b915babc  ...  2458129.908634  2459250.958634    21.9601
# 601d27d3da81920140939031  ...  2459250.958171  2459250.958634     -999.0
# 601d27d1739b2bb2412ca39b  ...  2458156.827859  2459250.958634     -999.0
# 601d27ca040c9a45b915bac7  ...  2458464.983657  2459250.958634     20.958
#
#                           sgscore2  distpsnr2     srmag3  sgscore3  distpsnr3  \
# 601cb75947230767c903ce48       1.0  11.778825     -999.0       0.5   15.36731
# 601cb758040c9a45b915243b  0.906845   5.796002  21.646299  0.923917  13.633864
# 601cb761da8192014092f81a     0.005   23.80216     -999.0    -999.0     -999.0
# 601cb75284abedb0473956ad   0.00125  29.997917     -999.0    -999.0     -999.0
# 601cb758da8192014092f80d       0.5   18.06329  20.993299   0.00125  18.108027
# ...                            ...        ...        ...       ...        ...
# 601d27da84abedb04739f084       0.5   4.848219     -999.0       0.5   7.036485
# 601d27ac040c9a45b915babc  0.921958  10.335657  21.554001  0.092458  21.886131
# 601d27d3da81920140939031    -999.0     -999.0     -999.0    -999.0     -999.0
# 601d27d1739b2bb2412ca39b  0.122494  16.965469     -999.0    -999.0     -999.0
# 601d27ca040c9a45b915bac7  0.982167   8.612084    21.4468       0.0  17.771406
#
#                                drb      objectId
# 601cb75947230767c903ce48  0.975172  ZTF18abyitqr
# 601cb758040c9a45b915243b  0.999086  ZTF20aafuwfv
# 601cb761da8192014092f81a  0.988304  ZTF20acekgfz
# 601cb75284abedb0473956ad  0.998478  ZTF20acmnhcd
# 601cb758da8192014092f80d  0.992726  ZTF18abuwcid
# ...                            ...           ...
# 601d27da84abedb04739f084  0.999998  ZTF21aahffzu
# 601d27ac040c9a45b915babc  0.999999  ZTF18aaacwwr
# 601d27d3da81920140939031  0.999995  ZTF21aahffzs
# 601d27d1739b2bb2412ca39b  0.999999  ZTF18acsuill
# 601d27ca040c9a45b915bac7       1.0  ZTF20acjqfyo
#
# [106560 rows x 24 columns]

# %%
# Open the file with the light curves
lc_filename = "data/fast_transient_lc.json"
  
# Opening JSON file
f = open(lc_filename)
  
# returns JSON object as a dictionary
lc_dict = json.load(f)

# %%
lc_dict
# Out:
# {'ZTF17aaabawq': [],
#  'ZTF17aaabqsi': [],
#  'ZTF17aaaddyq': [],
#  'ZTF17aaaealz': [],
#  'ZTF17aaaenhg': [],
#  'ZTF17aaaeosy': [],
#  'ZTF17aaaesnt': [],
#  'ZTF17aaagwog': [],
#  'ZTF17aaagymm': [],
#  'ZTF17aaahfli': [],
#  'ZTF17aaaiklw': [],
#  'ZTF17aaairdq': [],
#  'ZTF17aaaivsj': [],
#  'ZTF17aaaiwbh': [],
#  'ZTF17aaajexa': [],
#  'ZTF17aaajpfq': [],
#  'ZTF17aaajrol': [],
#  'ZTF17aaakdwk': [],
#  'ZTF17aaakpoj': [],
#  'ZTF17aaanssm': [],
#  'ZTF17aaaoabk': [{'jd': 2459221.90113,
#    'magpsf': 19.781,
#    'sigmapsf': 0.105,
#    'filter': 'r'},
#   {'jd': 2459223.95735, 'magpsf': 19.594, 'sigmapsf': 0.096, 'filter': 'r'},
#   {'jd': 2459230.86845, 'magpsf': 19.676, 'sigmapsf': 0.224, 'filter': 'r'},
#   {'jd': 2459230.86892, 'magpsf': 19.657, 'sigmapsf': 0.238, 'filter': 'r'},
#   {'jd': 2459231.87228, 'magpsf': 19.693, 'sigmapsf': 0.079, 'filter': 'r'},
#   {'jd': 2459231.89081, 'magpsf': 19.642, 'sigmapsf': 0.199, 'filter': 'r'},
#   {'jd': 2459249.87436, 'magpsf': 19.659, 'sigmapsf': 0.146, 'filter': 'r'},
#   {'jd': 2459250.83302, 'magpsf': 19.726, 'sigmapsf': 0.221, 'filter': 'r'},
#   {'jd': 2459250.8335, 'magpsf': 19.678, 'sigmapsf': 0.157, 'filter': 'r'},
#   {'jd': 2459251.82549, 'magpsf': 19.995, 'sigmapsf': 0.143, 'filter': 'r'},
#   {'jd': 2459253.83769, 'magpsf': 19.93, 'sigmapsf': 0.106, 'filter': 'r'},
#   {'jd': 2459263.88043, 'magpsf': 19.682, 'sigmapsf': 0.145, 'filter': 'r'},
#   {'jd': 2459275.81691, 'magpsf': 19.997, 'sigmapsf': 0.184, 'filter': 'r'}],
#  'ZTF17aaaoaxd': [],
#  'ZTF17aaaojxl': [],
#  'ZTF17aaapiez': [],
#  'ZTF17aaaukra': [],
#  'ZTF17aaawcwe': [],
#  'ZTF17aabimbg': [],
#  'ZTF17aabixbb': [],
#  'ZTF17aabncmt': [],
#  'ZTF17aabnena': [],
#  'ZTF17aabstqt': [],
#  'ZTF17aabudpu': [],
#  'ZTF17aabunpz': [],
#  'ZTF17aabuvao': [],
#  'ZTF17aabveul': [],
#  'ZTF17aabwkhm': [],
#  'ZTF17aabytmf': [],
#  'ZTF17aaceinv': [],
#  'ZTF17aacjznt': [],
#  'ZTF17aacmbor': [],
#  'ZTF17aacqeqs': [],
#  'ZTF17aacqgoz': [],
#  'ZTF17aadgurp': [],
#  'ZTF17aadjfef': [],
#  'ZTF17aadjggw': [],
#  'ZTF17aadksap': [],
#  'ZTF18aaablxh': [],
#  'ZTF18aaacige': [],
#  'ZTF18aaadiva': [],
#  'ZTF18aaadvvo': [],
#  'ZTF18aaaegsj': [],
#  'ZTF18aaafucu': [],
#  'ZTF18aaafvip': [],
#  'ZTF18aaafwqx': [],
#  'ZTF18aaagsfl': [],
#  'ZTF18aaagynu': [],
#  'ZTF18aaahcdd': [],
#  'ZTF18aaajfot': [],
#  'ZTF18aaajnfe': [],
#  'ZTF18aaalhnn': [],
#  'ZTF18aaamwrs': [],
#  'ZTF18aaardde': [],
#  'ZTF18aaasgau': [],
#  'ZTF18aaashhw': [],
#  'ZTF18aaayhph': [],
#  'ZTF18aaaynaa': [],
#  'ZTF18aabejqd': [],
#  'ZTF18aabfawy': [],
#  'ZTF18aabfcqu': [],
#  'ZTF18aabfmjv': [],
#  'ZTF18aabfpma': [],
#  'ZTF18aabfwcs': [],
#  'ZTF18aabgukr': [],
#  'ZTF18aabimts': [],
#  'ZTF18aabjgxc': [],
#  'ZTF18aabjmvk': [{'jd': 2459221.80601,
#    'magpsf': 15.271,
#    'sigmapsf': 0.04,
#    'filter': 'g'},
#   {'jd': 2459221.80698, 'magpsf': 15.302, 'sigmapsf': 0.037, 'filter': 'g'},
#   {'jd': 2459221.88975, 'magpsf': 15.29, 'sigmapsf': 0.044, 'filter': 'g'},
#   {'jd': 2459222.88391, 'magpsf': 15.388, 'sigmapsf': 0.034, 'filter': 'g'},
#   {'jd': 2459222.86366, 'magpsf': 15.46, 'sigmapsf': 0.035, 'filter': 'g'},
#   {'jd': 2459223.6761, 'magpsf': 15.323, 'sigmapsf': 0.072, 'filter': 'g'},
#   {'jd': 2459223.84946, 'magpsf': 15.424, 'sigmapsf': 0.044, 'filter': 'g'},
#   {'jd': 2459223.89368, 'magpsf': 15.357, 'sigmapsf': 0.055, 'filter': 'g'},
#   {'jd': 2459223.84804, 'magpsf': 15.399, 'sigmapsf': 0.045, 'filter': 'g'},
#   {'jd': 2459225.70659, 'magpsf': 15.416, 'sigmapsf': 0.051, 'filter': 'g'},
#   {'jd': 2459225.83646, 'magpsf': 15.421, 'sigmapsf': 0.051, 'filter': 'g'},
#   {'jd': 2459225.71818, 'magpsf': 15.448, 'sigmapsf': 0.029, 'filter': 'g'},
#   {'jd': 2459226.80626, 'magpsf': 15.406, 'sigmapsf': 0.058, 'filter': 'g'},
#   {'jd': 2459227.72397, 'magpsf': 15.52, 'sigmapsf': 0.056, 'filter': 'g'},
#   {'jd': 2459226.8072, 'magpsf': 15.398, 'sigmapsf': 0.046, 'filter': 'g'},
#   {'jd': 2459227.72491, 'magpsf': 15.46, 'sigmapsf': 0.055, 'filter': 'g'},
#   {'jd': 2459227.72584, 'magpsf': 15.609, 'sigmapsf': 0.057, 'filter': 'g'},
#   {'jd': 2459228.81073, 'magpsf': 15.525, 'sigmapsf': 0.04, 'filter': 'g'},
#   {'jd': 2459228.78523, 'magpsf': 15.391, 'sigmapsf': 0.092, 'filter': 'g'},
#   {'jd': 2459229.72346, 'magpsf': 15.803, 'sigmapsf': 0.064, 'filter': 'g'},
#   {'jd': 2459229.7244, 'magpsf': 15.514, 'sigmapsf': 0.044, 'filter': 'g'},
#   {'jd': 2459229.7225, 'magpsf': 15.509, 'sigmapsf': 0.044, 'filter': 'g'},
#   {'jd': 2459230.82072, 'magpsf': 15.624, 'sigmapsf': 0.059, 'filter': 'g'},
#   {'jd': 2459230.85866, 'magpsf': 15.428, 'sigmapsf': 0.053, 'filter': 'g'},
#   {'jd': 2459231.73653, 'magpsf': 15.508, 'sigmapsf': 0.034, 'filter': 'g'},
#   {'jd': 2459231.74477, 'magpsf': 15.443, 'sigmapsf': 0.042, 'filter': 'g'},
#   {'jd': 2459232.77858, 'magpsf': 15.435, 'sigmapsf': 0.052, 'filter': 'g'},
#   {'jd': 2459233.85329, 'magpsf': 15.474, 'sigmapsf': 0.066, 'filter': 'g'},
#   {'jd': 2459248.7252, 'magpsf': 15.005, 'sigmapsf': 0.065, 'filter': 'g'},
#   {'jd': 2459248.80969, 'magpsf': 14.333, 'sigmapsf': 0.072, 'filter': 'i'},
#   {'jd': 2459249.72405, 'magpsf': 14.978, 'sigmapsf': 0.057, 'filter': 'g'},
#   {'jd': 2459249.72503, 'magpsf': 15.045, 'sigmapsf': 0.045, 'filter': 'g'},
#   {'jd': 2459250.76968, 'magpsf': 14.991, 'sigmapsf': 0.037, 'filter': 'g'},
#   {'jd': 2459251.75832, 'magpsf': 15.031, 'sigmapsf': 0.012, 'filter': 'g'},
#   {'jd': 2459251.75975, 'magpsf': 15.026, 'sigmapsf': 0.045, 'filter': 'g'},
#   {'jd': 2459252.74688, 'magpsf': 15.029, 'sigmapsf': 0.047, 'filter': 'g'},
#   {'jd': 2459253.74134, 'magpsf': 15.117, 'sigmapsf': 0.04, 'filter': 'g'},
#   {'jd': 2459253.74228, 'magpsf': 14.962, 'sigmapsf': 0.046, 'filter': 'g'},
#   {'jd': 2459254.73987, 'magpsf': 15.027, 'sigmapsf': 0.033, 'filter': 'g'},
#   {'jd': 2459256.76922, 'magpsf': 15.09, 'sigmapsf': 0.06, 'filter': 'g'},
#   {'jd': 2459257.83065, 'magpsf': 15.603, 'sigmapsf': 0.063, 'filter': 'g'},
#   {'jd': 2459260.6974, 'magpsf': 15.266, 'sigmapsf': 0.051, 'filter': 'g'},
#   {'jd': 2459262.7614, 'magpsf': 14.51, 'sigmapsf': 0.04, 'filter': 'i'},
#   {'jd': 2459262.78041, 'magpsf': 15.44, 'sigmapsf': 0.044, 'filter': 'g'},
#   {'jd': 2459263.78131, 'magpsf': 15.356, 'sigmapsf': 0.045, 'filter': 'g'},
#   {'jd': 2459264.74192, 'magpsf': 15.544, 'sigmapsf': 0.032, 'filter': 'g'},
#   {'jd': 2459264.74292, 'magpsf': 15.244, 'sigmapsf': 0.054, 'filter': 'g'},
#   {'jd': 2459265.70047, 'magpsf': 15.444, 'sigmapsf': 0.06, 'filter': 'g'},
#   {'jd': 2459266.65441, 'magpsf': 15.361, 'sigmapsf': 0.057, 'filter': 'g'},
#   {'jd': 2459266.65539, 'magpsf': 15.544, 'sigmapsf': 0.037, 'filter': 'g'},
#   {'jd': 2459269.92741, 'magpsf': 15.509, 'sigmapsf': 0.07, 'filter': 'g'},
#   {'jd': 2459267.73679, 'magpsf': 15.446, 'sigmapsf': 0.039, 'filter': 'g'},
#   {'jd': 2459271.7225, 'magpsf': 15.604, 'sigmapsf': 0.033, 'filter': 'g'},
#   {'jd': 2459271.72344, 'magpsf': 15.558, 'sigmapsf': 0.044, 'filter': 'g'},
#   {'jd': 2459272.68374, 'magpsf': 15.714, 'sigmapsf': 0.042, 'filter': 'g'},
#   {'jd': 2459273.66285, 'magpsf': 15.535, 'sigmapsf': 0.065, 'filter': 'g'},
#   {'jd': 2459275.67976, 'magpsf': 15.499, 'sigmapsf': 0.051, 'filter': 'g'},
#   {'jd': 2459278.71773, 'magpsf': 15.412, 'sigmapsf': 0.031, 'filter': 'g'}],
#  'ZTF18aabkbvl': [],
#  'ZTF18aabtbbp': [],
#  'ZTF18aabtvlh': [],
#  'ZTF18aacnkns': [],
#  'ZTF18aaehclj': [],
#  'ZTF18aaewxxc': [{'jd': 2459221.90549,
#    'magpsf': 18.941,
#    'sigmapsf': 0.159,
#    'filter': 'r'},
#   {'jd': 2459229.92606, 'magpsf': 18.876, 'sigmapsf': 0.142, 'filter': 'r'},
#   {'jd': 2459229.94552, 'magpsf': 20.021, 'sigmapsf': 0.209, 'filter': 'g'},
#   {'jd': 2459250.80317, 'magpsf': 20.235, 'sigmapsf': 0.159, 'filter': 'g'},
#   {'jd': 2459250.88646, 'magpsf': 18.93, 'sigmapsf': 0.166, 'filter': 'r'},
#   {'jd': 2459252.80307, 'magpsf': 18.972, 'sigmapsf': 0.139, 'filter': 'r'},
#   {'jd': 2459252.86684, 'magpsf': 20.177, 'sigmapsf': 0.155, 'filter': 'g'},
#   {'jd': 2459254.80108, 'magpsf': 20.264, 'sigmapsf': 0.193, 'filter': 'g'},
#   {'jd': 2459262.82554, 'magpsf': 20.335, 'sigmapsf': 0.211, 'filter': 'g'},
#   {'jd': 2459262.84135, 'magpsf': 18.931, 'sigmapsf': 0.136, 'filter': 'r'},
#   {'jd': 2459262.90736, 'magpsf': 20.139, 'sigmapsf': 0.217, 'filter': 'g'},
#   {'jd': 2459263.74778, 'magpsf': 19.052, 'sigmapsf': 0.172, 'filter': 'r'},
#   {'jd': 2459263.86929, 'magpsf': 20.086, 'sigmapsf': 0.354, 'filter': 'g'},
#   {'jd': 2459264.84727, 'magpsf': 20.197, 'sigmapsf': 0.255, 'filter': 'g'}],
#  'ZTF18aafians': [],
#  'ZTF18aafluns': [{'jd': 2459221.93493,
#    'magpsf': 19.132,
#    'sigmapsf': 0.168,
#    'filter': 'g'},
#   {'jd': 2459222.83214, 'magpsf': 18.454, 'sigmapsf': 0.12, 'filter': 'r'},
#   {'jd': 2459222.86067, 'magpsf': 18.987, 'sigmapsf': 0.117, 'filter': 'g'},
#   {'jd': 2459222.86161, 'magpsf': 19.157, 'sigmapsf': 0.171, 'filter': 'g'},
#   {'jd': 2459223.86042, 'magpsf': 18.317, 'sigmapsf': 0.111, 'filter': 'r'},
#   {'jd': 2459224.83929, 'magpsf': 19.211, 'sigmapsf': 0.132, 'filter': 'g'},
#   {'jd': 2459225.854, 'magpsf': 19.111, 'sigmapsf': 0.148, 'filter': 'g'},
#   {'jd': 2459226.78546, 'magpsf': 18.391, 'sigmapsf': 0.079, 'filter': 'r'},
#   {'jd': 2459228.81815, 'magpsf': 18.273, 'sigmapsf': 0.119, 'filter': 'r'},
#   {'jd': 2459228.86703, 'magpsf': 18.979, 'sigmapsf': 0.127, 'filter': 'g'},
#   {'jd': 2459230.79208, 'magpsf': 18.387, 'sigmapsf': 0.108, 'filter': 'r'},
#   {'jd': 2459230.83823, 'magpsf': 19.005, 'sigmapsf': 0.114, 'filter': 'g'},
#   {'jd': 2459230.83917, 'magpsf': 19.185, 'sigmapsf': 0.126, 'filter': 'g'},
#   {'jd': 2459231.8166, 'magpsf': 18.178, 'sigmapsf': 0.099, 'filter': 'r'},
#   {'jd': 2459232.78762, 'magpsf': 18.961, 'sigmapsf': 0.145, 'filter': 'g'},
#   {'jd': 2459232.87425, 'magpsf': 18.451, 'sigmapsf': 0.15, 'filter': 'r'},
#   {'jd': 2459233.8187, 'magpsf': 18.986, 'sigmapsf': 0.101, 'filter': 'g'},
#   {'jd': 2459248.74875, 'magpsf': 18.195, 'sigmapsf': 0.077, 'filter': 'r'},
#   {'jd': 2459248.74969, 'magpsf': 18.421, 'sigmapsf': 0.094, 'filter': 'r'},
#   {'jd': 2459248.7686, 'magpsf': 18.872, 'sigmapsf': 0.139, 'filter': 'g'},
#   {'jd': 2459250.75617, 'magpsf': 18.865, 'sigmapsf': 0.111, 'filter': 'g'},
#   {'jd': 2459249.79662, 'magpsf': 18.185, 'sigmapsf': 0.128, 'filter': 'r'},
#   {'jd': 2459250.71466, 'magpsf': 18.004, 'sigmapsf': 0.111, 'filter': 'r'},
#   {'jd': 2459250.828, 'magpsf': 18.132, 'sigmapsf': 0.099, 'filter': 'r'},
#   {'jd': 2459251.727, 'magpsf': 18.159, 'sigmapsf': 0.092, 'filter': 'r'},
#   {'jd': 2459254.75373, 'magpsf': 18.126, 'sigmapsf': 0.128, 'filter': 'r'},
#   {'jd': 2459260.69159, 'magpsf': 18.886, 'sigmapsf': 0.163, 'filter': 'g'},
#   {'jd': 2459260.75046, 'magpsf': 18.001, 'sigmapsf': 0.118, 'filter': 'r'},
#   {'jd': 2459263.71326, 'magpsf': 18.158, 'sigmapsf': 0.158, 'filter': 'r'},
#   {'jd': 2459263.77641, 'magpsf': 19.062, 'sigmapsf': 0.134, 'filter': 'g'},
#   {'jd': 2459265.73278, 'magpsf': 18.087, 'sigmapsf': 0.121, 'filter': 'r'},
#   {'jd': 2459267.67403, 'magpsf': 18.285, 'sigmapsf': 0.141, 'filter': 'r'},
#   {'jd': 2459267.73476, 'magpsf': 18.584, 'sigmapsf': 0.1, 'filter': 'g'},
#   {'jd': 2459270.79438, 'magpsf': 18.181, 'sigmapsf': 0.109, 'filter': 'r'},
#   {'jd': 2459272.71181, 'magpsf': 17.929, 'sigmapsf': 0.086, 'filter': 'r'},
#   {'jd': 2459274.72553, 'magpsf': 18.559, 'sigmapsf': 0.112, 'filter': 'g'},
#   {'jd': 2459274.83593, 'magpsf': 17.863, 'sigmapsf': 0.091, 'filter': 'r'},
#   {'jd': 2459276.71069, 'magpsf': 18.447, 'sigmapsf': 0.101, 'filter': 'g'},
#   {'jd': 2459276.78003, 'magpsf': 17.989, 'sigmapsf': 0.1, 'filter': 'r'},
#   {'jd': 2459280.69072, 'magpsf': 18.604, 'sigmapsf': 0.063, 'filter': 'g'}],
#  'ZTF18aafuacm': [],
#  'ZTF18aagefry': [],
#  'ZTF18aagrccs': [],
#  'ZTF18aagrgba': [],
#  'ZTF18aagrjym': [],
#  'ZTF18aagseig': [],
#  'ZTF18aagwlpb': [],
#  'ZTF18aagwuzm': [],
#  'ZTF18aahaxht': [],
#  'ZTF18aahnhju': [],
#  'ZTF18aahssxk': [{'jd': 2459223.90483,
#    'magpsf': 20.645,
#    'sigmapsf': 0.294,
#    'filter': 'g'},
#   {'jd': 2459225.94507, 'magpsf': 20.359, 'sigmapsf': 0.302, 'filter': 'g'},
#   {'jd': 2459227.94344, 'magpsf': 20.676, 'sigmapsf': 0.216, 'filter': 'g'},
#   {'jd': 2459250.85906, 'magpsf': 20.255, 'sigmapsf': 0.213, 'filter': 'g'},
#   {'jd': 2459250.88066, 'magpsf': 20.396, 'sigmapsf': 0.203, 'filter': 'r'},
#   {'jd': 2459252.99147, 'magpsf': 20.275, 'sigmapsf': 0.168, 'filter': 'g'},
#   {'jd': 2459254.90069, 'magpsf': 20.561, 'sigmapsf': 0.219, 'filter': 'r'},
#   {'jd': 2459256.99277, 'magpsf': 20.373, 'sigmapsf': 0.185, 'filter': 'g'},
#   {'jd': 2459260.90281, 'magpsf': 20.295, 'sigmapsf': 0.265, 'filter': 'r'},
#   {'jd': 2459263.85963, 'magpsf': 20.307, 'sigmapsf': 0.377, 'filter': 'g'},
#   {'jd': 2459265.87164, 'magpsf': 20.564, 'sigmapsf': 0.215, 'filter': 'r'},
#   {'jd': 2459278.80014, 'magpsf': 20.345, 'sigmapsf': 0.196, 'filter': 'g'},
#   {'jd': 2459278.81954, 'magpsf': 20.611, 'sigmapsf': 0.299, 'filter': 'g'}],
#  'ZTF18aahsyvy': [{'jd': 2459221.94428,
#    'magpsf': 19.739,
#    'sigmapsf': 0.158,
#    'filter': 'r'},
#   {'jd': 2459221.98228, 'magpsf': 20.338, 'sigmapsf': 0.294, 'filter': 'g'},
#   {'jd': 2459223.90015, 'magpsf': 20.158, 'sigmapsf': 0.242, 'filter': 'g'},
#   {'jd': 2459223.98161, 'magpsf': 19.542, 'sigmapsf': 0.149, 'filter': 'r'},
#   {'jd': 2459225.96455, 'magpsf': 20.415, 'sigmapsf': 0.292, 'filter': 'g'},
#   {'jd': 2459227.96179, 'magpsf': 20.312, 'sigmapsf': 0.247, 'filter': 'g'},
#   {'jd': 2459230.00395, 'magpsf': 19.696, 'sigmapsf': 0.213, 'filter': 'r'},
#   {'jd': 2459231.95822, 'magpsf': 20.772, 'sigmapsf': 0.313, 'filter': 'g'},
#   {'jd': 2459248.92001, 'magpsf': 19.978, 'sigmapsf': 0.187, 'filter': 'r'},
#   {'jd': 2459250.90351, 'magpsf': 20.017, 'sigmapsf': 0.176, 'filter': 'r'},
#   {'jd': 2459252.8697, 'magpsf': 20.352, 'sigmapsf': 0.167, 'filter': 'r'}],
#  'ZTF18aaisdee': [],
#  'ZTF18aaiywne': [],
#  'ZTF18aaizuov': [],
#  'ZTF18aajgtio': [],
#  'ZTF18aajsghk': [],
#  'ZTF18aakbhtv': [],
#  'ZTF18aakgfid': [],
#  'ZTF18aakgrgf': [],
#  'ZTF18aalfzbp': [],
#  'ZTF18aamqgts': [],
#  'ZTF18aandcit': [],
#  'ZTF18aaotxex': [],
#  'ZTF18aaowqnf': [],
#  'ZTF18aapdkvt': [],
#  'ZTF18aaqnrwl': [],
#  'ZTF18aaqovmg': [],
#  'ZTF18aarvozv': [{'jd': 2459224.04905,
#    'magpsf': 20.539,
#    'sigmapsf': 0.329,
#    'filter': 'g'},
#   {'jd': 2459224.05596, 'magpsf': 20.205, 'sigmapsf': 0.254, 'filter': 'g'},
#   {'jd': 2459225.02479, 'magpsf': 20.129, 'sigmapsf': 0.196, 'filter': 'g'},
#   {'jd': 2459227.03167, 'magpsf': 20.417, 'sigmapsf': 0.244, 'filter': 'g'},
#   {'jd': 2459227.0326, 'magpsf': 20.27, 'sigmapsf': 0.243, 'filter': 'g'},
#   {'jd': 2459227.9756, 'magpsf': 20.222, 'sigmapsf': 0.274, 'filter': 'g'},
#   {'jd': 2459229.01009, 'magpsf': 20.441, 'sigmapsf': 0.269, 'filter': 'g'},
#   {'jd': 2459233.03199, 'magpsf': 20.467, 'sigmapsf': 0.207, 'filter': 'g'},
#   {'jd': 2459233.03292, 'magpsf': 20.219, 'sigmapsf': 0.179, 'filter': 'g'},
#   {'jd': 2459248.9763, 'magpsf': 20.295, 'sigmapsf': 0.287, 'filter': 'g'},
#   {'jd': 2459249.99398, 'magpsf': 20.224, 'sigmapsf': 0.226, 'filter': 'r'}],
#  'ZTF18aasuwrv': [],
#  'ZTF18aautoos': [],
#  'ZTF18aauupaw': [],
#  'ZTF18aavskac': [],
#  'ZTF18aawnzpb': [],
#  'ZTF18aaxjunc': [],
#  'ZTF18aayklzi': [],
#  'ZTF18abavrdw': [],
#  'ZTF18abboanz': [],
#  'ZTF18abbvrpu': [],
#  'ZTF18abbvrqj': [],
#  'ZTF18abcecxd': [],
#  'ZTF18abchhlc': [],
#  'ZTF18abcojcr': [],
#  'ZTF18abdgddh': [],
#  'ZTF18abdkfhp': [],
#  'ZTF18abegymn': [],
#  'ZTF18abfhxzf': [],
#  'ZTF18abflrog': [],
#  'ZTF18abgpxqf': [{'jd': 2459250.63463,
#    'magpsf': 19.612,
#    'sigmapsf': 0.164,
#    'filter': 'g'},
#   {'jd': 2459250.68146, 'magpsf': 19.632, 'sigmapsf': 0.227, 'filter': 'r'},
#   {'jd': 2459252.6401, 'magpsf': 19.963, 'sigmapsf': 0.198, 'filter': 'g'},
#   {'jd': 2459252.66444, 'magpsf': 19.593, 'sigmapsf': 0.144, 'filter': 'r'},
#   {'jd': 2459254.63703, 'magpsf': 20.242, 'sigmapsf': 0.281, 'filter': 'g'},
#   {'jd': 2459254.66017, 'magpsf': 20.158, 'sigmapsf': 0.237, 'filter': 'r'}],
#  'ZTF18abgufrs': [],
#  'ZTF18abilnxt': [],
#  'ZTF18abjhsso': [{'jd': 2459221.61922,
#    'magpsf': 16.721,
#    'sigmapsf': 0.081,
#    'filter': 'r'},
#   {'jd': 2459221.62024, 'magpsf': 16.809, 'sigmapsf': 0.1, 'filter': 'r'},
#   {'jd': 2459221.6347, 'magpsf': 17.628, 'sigmapsf': 0.126, 'filter': 'g'},
#   {'jd': 2459221.63612, 'magpsf': 17.559, 'sigmapsf': 0.062, 'filter': 'g'},
#   {'jd': 2459221.69756, 'magpsf': 17.081, 'sigmapsf': 0.144, 'filter': 'r'},
#   {'jd': 2459223.61698, 'magpsf': 17.122, 'sigmapsf': 0.055, 'filter': 'r'},
#   {'jd': 2459223.61558, 'magpsf': 17.288, 'sigmapsf': 0.107, 'filter': 'r'},
#   {'jd': 2459223.65683, 'magpsf': 17.746, 'sigmapsf': 0.059, 'filter': 'g'},
#   {'jd': 2459225.61338, 'magpsf': 17.655, 'sigmapsf': 0.08, 'filter': 'g'},
#   {'jd': 2459223.63759, 'magpsf': 17.762, 'sigmapsf': 0.067, 'filter': 'g'},
#   {'jd': 2459225.68236, 'magpsf': 16.819, 'sigmapsf': 0.06, 'filter': 'r'},
#   {'jd': 2459225.6819, 'magpsf': 17.177, 'sigmapsf': 0.054, 'filter': 'r'},
#   {'jd': 2459227.61615, 'magpsf': 17.905, 'sigmapsf': 0.101, 'filter': 'g'},
#   {'jd': 2459227.61708, 'magpsf': 17.746, 'sigmapsf': 0.048, 'filter': 'g'},
#   {'jd': 2459227.65451, 'magpsf': 17.144, 'sigmapsf': 0.049, 'filter': 'r'},
#   {'jd': 2459227.65499, 'magpsf': 17.125, 'sigmapsf': 0.062, 'filter': 'r'},
#   {'jd': 2459229.6172, 'magpsf': 17.013, 'sigmapsf': 0.049, 'filter': 'r'},
#   {'jd': 2459229.61766, 'magpsf': 16.994, 'sigmapsf': 0.045, 'filter': 'r'},
#   {'jd': 2459231.6209, 'magpsf': 17.779, 'sigmapsf': 0.095, 'filter': 'g'},
#   {'jd': 2459231.61903, 'magpsf': 17.855, 'sigmapsf': 0.063, 'filter': 'g'},
#   {'jd': 2459231.65432, 'magpsf': 17.019, 'sigmapsf': 0.083, 'filter': 'r'},
#   {'jd': 2459231.65478, 'magpsf': 17.04, 'sigmapsf': 0.053, 'filter': 'r'},
#   {'jd': 2459233.63828, 'magpsf': 17.848, 'sigmapsf': 0.094, 'filter': 'g'},
#   {'jd': 2459250.63937, 'magpsf': 17.932, 'sigmapsf': 0.091, 'filter': 'g'}],
#  'ZTF18abkftwm': [{'jd': 2459222.0097,
#    'magpsf': 19.616,
#    'sigmapsf': 0.236,
#    'filter': 'g'},
#   {'jd': 2459222.01064, 'magpsf': 19.266, 'sigmapsf': 0.162, 'filter': 'g'},
#   {'jd': 2459225.0159, 'magpsf': 19.255, 'sigmapsf': 0.185, 'filter': 'r'},
#   {'jd': 2459222.05245, 'magpsf': 19.202, 'sigmapsf': 0.208, 'filter': 'r'},
#   {'jd': 2459225.05369, 'magpsf': 19.252, 'sigmapsf': 0.173, 'filter': 'g'},
#   {'jd': 2459226.99771, 'magpsf': 19.07, 'sigmapsf': 0.196, 'filter': 'r'},
#   {'jd': 2459227.99443, 'magpsf': 19.16, 'sigmapsf': 0.172, 'filter': 'g'},
#   {'jd': 2459228.05302, 'magpsf': 19.181, 'sigmapsf': 0.24, 'filter': 'r'},
#   {'jd': 2459227.03547, 'magpsf': 19.315, 'sigmapsf': 0.116, 'filter': 'g'},
#   {'jd': 2459229.05302, 'magpsf': 19.121, 'sigmapsf': 0.196, 'filter': 'i'},
#   {'jd': 2459230.98791, 'magpsf': 19.129, 'sigmapsf': 0.169, 'filter': 'g'},
#   {'jd': 2459230.98884, 'magpsf': 19.272, 'sigmapsf': 0.185, 'filter': 'g'},
#   {'jd': 2459231.04806, 'magpsf': 19.288, 'sigmapsf': 0.142, 'filter': 'r'},
#   {'jd': 2459231.05135, 'magpsf': 19.02, 'sigmapsf': 0.139, 'filter': 'r'},
#   {'jd': 2459232.996, 'magpsf': 19.159, 'sigmapsf': 0.107, 'filter': 'r'},
#   {'jd': 2459232.99692, 'magpsf': 19.215, 'sigmapsf': 0.127, 'filter': 'r'},
#   {'jd': 2459233.03721, 'magpsf': 19.346, 'sigmapsf': 0.122, 'filter': 'g'},
#   {'jd': 2459233.03818, 'magpsf': 19.38, 'sigmapsf': 0.117, 'filter': 'g'},
#   {'jd': 2459249.00652, 'magpsf': 18.958, 'sigmapsf': 0.099, 'filter': 'g'},
#   {'jd': 2459249.03713, 'magpsf': 19.281, 'sigmapsf': 0.216, 'filter': 'r'},
#   {'jd': 2459250.0211, 'magpsf': 19.036, 'sigmapsf': 0.117, 'filter': 'r'},
#   {'jd': 2459250.02016, 'magpsf': 19.037, 'sigmapsf': 0.124, 'filter': 'r'},
#   {'jd': 2459250.03001, 'magpsf': 19.061, 'sigmapsf': 0.131, 'filter': 'g'},
#   {'jd': 2459250.03095, 'magpsf': 18.963, 'sigmapsf': 0.142, 'filter': 'g'},
#   {'jd': 2459250.98563, 'magpsf': 19.06, 'sigmapsf': 0.111, 'filter': 'g'},
#   {'jd': 2459251.03029, 'magpsf': 18.916, 'sigmapsf': 0.113, 'filter': 'r'},
#   {'jd': 2459252.04289, 'magpsf': 18.978, 'sigmapsf': 0.115, 'filter': 'g'},
#   {'jd': 2459251.99053, 'magpsf': 19.046, 'sigmapsf': 0.124, 'filter': 'r'},
#   {'jd': 2459255.04275, 'magpsf': 18.809, 'sigmapsf': 0.233, 'filter': 'g'},
#   {'jd': 2459251.99147, 'magpsf': 18.979, 'sigmapsf': 0.152, 'filter': 'r'},
#   {'jd': 2459252.04557, 'magpsf': 19.018, 'sigmapsf': 0.136, 'filter': 'g'},
#   {'jd': 2459256.92839, 'magpsf': 19.033, 'sigmapsf': 0.113, 'filter': 'r'},
#   {'jd': 2459256.92933, 'magpsf': 19.078, 'sigmapsf': 0.105, 'filter': 'r'},
#   {'jd': 2459257.04252, 'magpsf': 19.05, 'sigmapsf': 0.111, 'filter': 'g'},
#   {'jd': 2459257.04346, 'magpsf': 19.048, 'sigmapsf': 0.086, 'filter': 'g'},
#   {'jd': 2459258.98775, 'magpsf': 18.993, 'sigmapsf': 0.187, 'filter': 'r'},
#   {'jd': 2459258.99345, 'magpsf': 19.014, 'sigmapsf': 0.102, 'filter': 'r'},
#   {'jd': 2459259.03586, 'magpsf': 19.034, 'sigmapsf': 0.138, 'filter': 'g'},
#   {'jd': 2459259.03679, 'magpsf': 18.939, 'sigmapsf': 0.137, 'filter': 'g'},
#   {'jd': 2459263.9858, 'magpsf': 19.037, 'sigmapsf': 0.15, 'filter': 'r'},
#   {'jd': 2459263.98674, 'magpsf': 19.139, 'sigmapsf': 0.155, 'filter': 'r'},
#   {'jd': 2459263.98483, 'magpsf': 19.214, 'sigmapsf': 0.184, 'filter': 'r'},
#   {'jd': 2459264.02492, 'magpsf': 18.997, 'sigmapsf': 0.139, 'filter': 'g'},
#   {'jd': 2459264.02589, 'magpsf': 18.994, 'sigmapsf': 0.118, 'filter': 'g'},
#   {'jd': 2459264.98712, 'magpsf': 19.013, 'sigmapsf': 0.095, 'filter': 'g'},
#   {'jd': 2459264.99727, 'magpsf': 19.0, 'sigmapsf': 0.103, 'filter': 'g'},
#   {'jd': 2459266.0064, 'magpsf': 19.083, 'sigmapsf': 0.112, 'filter': 'g'},
#   {'jd': 2459266.03844, 'magpsf': 18.851, 'sigmapsf': 0.09, 'filter': 'r'},
#   {'jd': 2459265.03758, 'magpsf': 18.934, 'sigmapsf': 0.114, 'filter': 'r'},
#   {'jd': 2459267.92773, 'magpsf': 18.694, 'sigmapsf': 0.158, 'filter': 'r'},
#   {'jd': 2459265.02615, 'magpsf': 18.93, 'sigmapsf': 0.09, 'filter': 'r'},
#   {'jd': 2459268.00743, 'magpsf': 19.165, 'sigmapsf': 0.132, 'filter': 'i'},
#   {'jd': 2459268.97531, 'magpsf': 18.861, 'sigmapsf': 0.126, 'filter': 'r'},
#   {'jd': 2459269.00771, 'magpsf': 19.024, 'sigmapsf': 0.101, 'filter': 'g'},
#   {'jd': 2459269.96873, 'magpsf': 19.015, 'sigmapsf': 0.137, 'filter': 'g'},
#   {'jd': 2459269.96968, 'magpsf': 18.918, 'sigmapsf': 0.118, 'filter': 'g'},
#   {'jd': 2459270.02248, 'magpsf': 18.942, 'sigmapsf': 0.127, 'filter': 'r'},
#   {'jd': 2459270.03479, 'magpsf': 18.858, 'sigmapsf': 0.082, 'filter': 'r'},
#   {'jd': 2459270.95681, 'magpsf': 19.268, 'sigmapsf': 0.246, 'filter': 'g'},
#   {'jd': 2459271.01878, 'magpsf': 19.013, 'sigmapsf': 0.109, 'filter': 'r'},
#   {'jd': 2459272.96752, 'magpsf': 18.99, 'sigmapsf': 0.139, 'filter': 'r'},
#   {'jd': 2459272.96846, 'magpsf': 18.83, 'sigmapsf': 0.113, 'filter': 'r'},
#   {'jd': 2459273.02593, 'magpsf': 18.872, 'sigmapsf': 0.115, 'filter': 'g'},
#   {'jd': 2459273.02687, 'magpsf': 19.059, 'sigmapsf': 0.161, 'filter': 'g'},
#   {'jd': 2459274.98324, 'magpsf': 19.015, 'sigmapsf': 0.217, 'filter': 'g'},
#   {'jd': 2459275.00874, 'magpsf': 18.921, 'sigmapsf': 0.15, 'filter': 'r'},
#   {'jd': 2459275.9913, 'magpsf': 18.966, 'sigmapsf': 0.173, 'filter': 'g'},
#   {'jd': 2459275.99222, 'magpsf': 19.127, 'sigmapsf': 0.157, 'filter': 'g'},
#   {'jd': 2459277.02551, 'magpsf': 19.294, 'sigmapsf': 0.169, 'filter': 'i'},
#   {'jd': 2459278.98477, 'magpsf': 19.008, 'sigmapsf': 0.145, 'filter': 'r'},
#   {'jd': 2459278.98571, 'magpsf': 18.906, 'sigmapsf': 0.118, 'filter': 'r'},
#   {'jd': 2459279.01267, 'magpsf': 18.93, 'sigmapsf': 0.121, 'filter': 'g'},
#   {'jd': 2459279.01174, 'magpsf': 18.828, 'sigmapsf': 0.091, 'filter': 'g'}],
#  'ZTF18ablwoue': [],
#  'ZTF18abmnxoc': [{'jd': 2459221.69998,
#    'magpsf': 18.395,
#    'sigmapsf': 0.076,
#    'filter': 'r'},
#   {'jd': 2459222.74737, 'magpsf': 19.06, 'sigmapsf': 0.141, 'filter': 'g'},
#   {'jd': 2459223.61463, 'magpsf': 18.286, 'sigmapsf': 0.075, 'filter': 'r'},
#   {'jd': 2459223.63661, 'magpsf': 18.79, 'sigmapsf': 0.1, 'filter': 'g'},
#   {'jd': 2459223.71881, 'magpsf': 18.196, 'sigmapsf': 0.118, 'filter': 'i'},
#   {'jd': 2459224.61316, 'magpsf': 18.492, 'sigmapsf': 0.089, 'filter': 'r'},
#   {'jd': 2459224.67638, 'magpsf': 19.011, 'sigmapsf': 0.19, 'filter': 'g'},
#   {'jd': 2459224.67731, 'magpsf': 18.951, 'sigmapsf': 0.131, 'filter': 'g'},
#   {'jd': 2459225.62034, 'magpsf': 19.112, 'sigmapsf': 0.234, 'filter': 'g'},
#   {'jd': 2459226.61586, 'magpsf': 18.231, 'sigmapsf': 0.079, 'filter': 'r'},
#   {'jd': 2459225.68424, 'magpsf': 18.452, 'sigmapsf': 0.11, 'filter': 'r'},
#   {'jd': 2459226.68514, 'magpsf': 18.947, 'sigmapsf': 0.17, 'filter': 'g'},
#   {'jd': 2459227.65687, 'magpsf': 18.394, 'sigmapsf': 0.105, 'filter': 'r'},
#   {'jd': 2459228.62218, 'magpsf': 18.116, 'sigmapsf': 0.084, 'filter': 'r'},
#   {'jd': 2459228.65719, 'magpsf': 18.754, 'sigmapsf': 0.119, 'filter': 'g'},
#   {'jd': 2459228.65814, 'magpsf': 18.814, 'sigmapsf': 0.136, 'filter': 'g'},
#   {'jd': 2459229.61576, 'magpsf': 18.58, 'sigmapsf': 0.116, 'filter': 'r'},
#   {'jd': 2459229.6556, 'magpsf': 18.185, 'sigmapsf': 0.15, 'filter': 'i'},
#   {'jd': 2459229.70377, 'magpsf': 18.989, 'sigmapsf': 0.22, 'filter': 'g'},
#   {'jd': 2459230.61873, 'magpsf': 18.446, 'sigmapsf': 0.124, 'filter': 'r'},
#   {'jd': 2459230.61968, 'magpsf': 18.474, 'sigmapsf': 0.077, 'filter': 'r'},
#   {'jd': 2459230.65042, 'magpsf': 18.969, 'sigmapsf': 0.104, 'filter': 'g'},
#   {'jd': 2459230.65808, 'magpsf': 18.962, 'sigmapsf': 0.151, 'filter': 'g'},
#   {'jd': 2459231.61569, 'magpsf': 18.802, 'sigmapsf': 0.11, 'filter': 'g'},
#   {'jd': 2459232.61824, 'magpsf': 19.23, 'sigmapsf': 0.19, 'filter': 'g'},
#   {'jd': 2459231.65287, 'magpsf': 18.32, 'sigmapsf': 0.098, 'filter': 'r'},
#   {'jd': 2459232.65813, 'magpsf': 18.707, 'sigmapsf': 0.121, 'filter': 'r'},
#   {'jd': 2459248.64016, 'magpsf': 18.747, 'sigmapsf': 0.092, 'filter': 'g'},
#   {'jd': 2459250.63699, 'magpsf': 18.702, 'sigmapsf': 0.105, 'filter': 'g'},
#   {'jd': 2459250.68287, 'magpsf': 18.149, 'sigmapsf': 0.094, 'filter': 'r'},
#   {'jd': 2459252.63869, 'magpsf': 19.138, 'sigmapsf': 0.154, 'filter': 'g'},
#   {'jd': 2459252.66209, 'magpsf': 18.484, 'sigmapsf': 0.099, 'filter': 'r'},
#   {'jd': 2459254.63561, 'magpsf': 18.669, 'sigmapsf': 0.098, 'filter': 'g'},
#   {'jd': 2459256.63625, 'magpsf': 18.73, 'sigmapsf': 0.093, 'filter': 'g'},
#   {'jd': 2459256.65588, 'magpsf': 18.281, 'sigmapsf': 0.064, 'filter': 'r'},
#   {'jd': 2459260.64253, 'magpsf': 18.899, 'sigmapsf': 0.15, 'filter': 'g'},
#   {'jd': 2459260.65757, 'magpsf': 18.159, 'sigmapsf': 0.083, 'filter': 'r'},
#   {'jd': 2459263.6456, 'magpsf': 18.535, 'sigmapsf': 0.136, 'filter': 'g'},
#   {'jd': 2459263.67837, 'magpsf': 17.989, 'sigmapsf': 0.086, 'filter': 'r'},
#   {'jd': 2459265.64444, 'magpsf': 18.374, 'sigmapsf': 0.09, 'filter': 'r'}],
#  'ZTF18abmnyel': [],
#  'ZTF18abmsnvy': [],
#  'ZTF18abnckrj': [],
#  'ZTF18abnncit': [],
#  'ZTF18abnomhi': [],
#  'ZTF18abnyvbe': [],
#  'ZTF18abnzefr': [],
#  'ZTF18aborwbi': [],
#  'ZTF18abotfbq': [],
#  'ZTF18abppqjh': [],
#  'ZTF18abpvpzx': [],
#  'ZTF18abscieg': [],
#  'ZTF18absciom': [],
#  'ZTF18abspqtu': [],
#  'ZTF18absqjuk': [],
#  'ZTF18abstdrr': [],
#  'ZTF18abtcfoo': [{'jd': 2459222.74737,
#    'magpsf': 19.106,
#    'sigmapsf': 0.152,
#    'filter': 'g'},
#   {'jd': 2459223.61463, 'magpsf': 18.224, 'sigmapsf': 0.12, 'filter': 'r'},
#   {'jd': 2459223.65845, 'magpsf': 19.093, 'sigmapsf': 0.139, 'filter': 'g'},
#   {'jd': 2459224.61222, 'magpsf': 18.906, 'sigmapsf': 0.138, 'filter': 'r'},
#   {'jd': 2459224.64494, 'magpsf': 18.918, 'sigmapsf': 0.152, 'filter': 'r'},
#   {'jd': 2459224.67685, 'magpsf': 19.445, 'sigmapsf': 0.168, 'filter': 'g'},
#   {'jd': 2459223.63661, 'magpsf': 19.007, 'sigmapsf': 0.127, 'filter': 'g'},
#   {'jd': 2459224.67731, 'magpsf': 19.388, 'sigmapsf': 0.203, 'filter': 'g'},
#   {'jd': 2459226.61586, 'magpsf': 18.405, 'sigmapsf': 0.092, 'filter': 'r'},
#   {'jd': 2459226.61633, 'magpsf': 18.45, 'sigmapsf': 0.123, 'filter': 'r'},
#   {'jd': 2459226.66076, 'magpsf': 18.604, 'sigmapsf': 0.172, 'filter': 'r'},
#   {'jd': 2459226.67935, 'magpsf': 18.759, 'sigmapsf': 0.14, 'filter': 'g'},
#   {'jd': 2459223.74507, 'magpsf': 18.357, 'sigmapsf': 0.095, 'filter': 'r'},
#   {'jd': 2459226.70053, 'magpsf': 18.876, 'sigmapsf': 0.148, 'filter': 'g'},
#   {'jd': 2459224.67638, 'magpsf': 19.392, 'sigmapsf': 0.176, 'filter': 'g'},
#   {'jd': 2459226.68514, 'magpsf': 19.149, 'sigmapsf': 0.24, 'filter': 'g'},
#   {'jd': 2459227.65641, 'magpsf': 18.657, 'sigmapsf': 0.141, 'filter': 'r'},
#   {'jd': 2459227.65687, 'magpsf': 18.598, 'sigmapsf': 0.109, 'filter': 'r'},
#   {'jd': 2459227.67306, 'magpsf': 19.202, 'sigmapsf': 0.233, 'filter': 'g'},
#   {'jd': 2459227.67258, 'magpsf': 19.297, 'sigmapsf': 0.19, 'filter': 'g'},
#   {'jd': 2459229.61576, 'magpsf': 18.686, 'sigmapsf': 0.155, 'filter': 'r'},
#   {'jd': 2459229.63918, 'magpsf': 18.565, 'sigmapsf': 0.116, 'filter': 'r'},
#   {'jd': 2459229.6556, 'magpsf': 18.422, 'sigmapsf': 0.147, 'filter': 'i'},
#   {'jd': 2459229.70377, 'magpsf': 19.248, 'sigmapsf': 0.271, 'filter': 'g'},
#   {'jd': 2459230.61826, 'magpsf': 18.375, 'sigmapsf': 0.116, 'filter': 'r'},
#   {'jd': 2459230.61873, 'magpsf': 18.242, 'sigmapsf': 0.104, 'filter': 'r'},
#   {'jd': 2459230.61968, 'magpsf': 18.407, 'sigmapsf': 0.104, 'filter': 'r'},
#   {'jd': 2459230.6192, 'magpsf': 18.46, 'sigmapsf': 0.1, 'filter': 'r'},
#   {'jd': 2459230.65808, 'magpsf': 19.035, 'sigmapsf': 0.178, 'filter': 'g'},
#   {'jd': 2459230.65042, 'magpsf': 19.122, 'sigmapsf': 0.132, 'filter': 'g'},
#   {'jd': 2459230.68427, 'magpsf': 19.059, 'sigmapsf': 0.123, 'filter': 'g'},
#   {'jd': 2459229.68273, 'magpsf': 19.317, 'sigmapsf': 0.206, 'filter': 'g'},
#   {'jd': 2459231.61569, 'magpsf': 19.319, 'sigmapsf': 0.121, 'filter': 'g'},
#   {'jd': 2459231.65333, 'magpsf': 18.816, 'sigmapsf': 0.192, 'filter': 'r'},
#   {'jd': 2459231.67632, 'magpsf': 18.973, 'sigmapsf': 0.128, 'filter': 'r'},
#   {'jd': 2459233.64354, 'magpsf': 19.453, 'sigmapsf': 0.237, 'filter': 'g'},
#   {'jd': 2459233.64888, 'magpsf': 19.079, 'sigmapsf': 0.128, 'filter': 'g'},
#   {'jd': 2459248.64016, 'magpsf': 19.271, 'sigmapsf': 0.19, 'filter': 'g'},
#   {'jd': 2459248.6997, 'magpsf': 19.236, 'sigmapsf': 0.151, 'filter': 'g'},
#   {'jd': 2459248.70017, 'magpsf': 19.256, 'sigmapsf': 0.165, 'filter': 'g'},
#   {'jd': 2459250.63652, 'magpsf': 19.366, 'sigmapsf': 0.13, 'filter': 'g'},
#   {'jd': 2459250.63745, 'magpsf': 19.437, 'sigmapsf': 0.171, 'filter': 'g'},
#   {'jd': 2459250.68334, 'magpsf': 19.119, 'sigmapsf': 0.178, 'filter': 'r'},
#   {'jd': 2459252.63823, 'magpsf': 19.216, 'sigmapsf': 0.149, 'filter': 'g'},
#   {'jd': 2459252.66209, 'magpsf': 18.457, 'sigmapsf': 0.123, 'filter': 'r'},
#   {'jd': 2459256.63625, 'magpsf': 19.32, 'sigmapsf': 0.19, 'filter': 'g'},
#   {'jd': 2459256.63578, 'magpsf': 19.452, 'sigmapsf': 0.18, 'filter': 'g'},
#   {'jd': 2459256.65588, 'magpsf': 18.874, 'sigmapsf': 0.151, 'filter': 'r'},
#   {'jd': 2459260.64206, 'magpsf': 19.405, 'sigmapsf': 0.189, 'filter': 'g'},
#   {'jd': 2459260.64253, 'magpsf': 19.397, 'sigmapsf': 0.267, 'filter': 'g'},
#   {'jd': 2459262.65194, 'magpsf': 19.042, 'sigmapsf': 0.176, 'filter': 'g'},
#   {'jd': 2459263.64514, 'magpsf': 19.057, 'sigmapsf': 0.194, 'filter': 'g'},
#   {'jd': 2459263.6456, 'magpsf': 19.128, 'sigmapsf': 0.259, 'filter': 'g'},
#   {'jd': 2459265.64398, 'magpsf': 18.759, 'sigmapsf': 0.198, 'filter': 'r'},
#   {'jd': 2459264.63821, 'magpsf': 19.616, 'sigmapsf': 0.166, 'filter': 'g'},
#   {'jd': 2459265.64444, 'magpsf': 18.513, 'sigmapsf': 0.146, 'filter': 'r'},
#   {'jd': 2459265.66191, 'magpsf': 19.198, 'sigmapsf': 0.221, 'filter': 'g'}],
#  'ZTF18abtecgr': [],
#  'ZTF18abtpkfz': [],
#  'ZTF18abtrvzr': [],
#  'ZTF18abtsdmx': [],
#  'ZTF18abujdvn': [],
#  'ZTF18abupviz': [],
#  'ZTF18abuvwpr': [],
#  'ZTF18abveklb': [],
#  'ZTF18abvexxq': [],
#  'ZTF18abvgghl': [],
#  'ZTF18abvlhxv': [],
#  'ZTF18abvlizf': [],
#  'ZTF18abvmiao': [],
#  'ZTF18abvtufv': [{'jd': 2459221.85383,
#    'magpsf': 16.216,
#    'sigmapsf': 0.083,
#    'filter': 'g'},
#   {'jd': 2459221.89022, 'magpsf': 16.36, 'sigmapsf': 0.025, 'filter': 'g'},
#   {'jd': 2459221.75657, 'magpsf': 15.416, 'sigmapsf': 0.054, 'filter': 'r'},
#   {'jd': 2459221.91285, 'magpsf': 15.134, 'sigmapsf': 0.069, 'filter': 'r'},
#   {'jd': 2459222.80579, 'magpsf': 16.185, 'sigmapsf': 0.092, 'filter': 'g'},
#   {'jd': 2459222.84205, 'magpsf': 15.248, 'sigmapsf': 0.119, 'filter': 'r'},
#   {'jd': 2459221.93391, 'magpsf': 16.145, 'sigmapsf': 0.061, 'filter': 'g'},
#   {'jd': 2459222.84299, 'magpsf': 15.372, 'sigmapsf': 0.067, 'filter': 'r'},
#   {'jd': 2459222.84395, 'magpsf': 15.216, 'sigmapsf': 0.072, 'filter': 'r'},
#   {'jd': 2459222.88437, 'magpsf': 16.182, 'sigmapsf': 0.063, 'filter': 'g'},
#   {'jd': 2459222.91111, 'magpsf': 16.109, 'sigmapsf': 0.095, 'filter': 'g'},
#   {'jd': 2459223.67991, 'magpsf': 16.256, 'sigmapsf': 0.08, 'filter': 'g'},
#   {'jd': 2459222.88534, 'magpsf': 16.097, 'sigmapsf': 0.061, 'filter': 'g'},
#   {'jd': 2459223.78051, 'magpsf': 15.255, 'sigmapsf': 0.071, 'filter': 'r'},
#   {'jd': 2459223.80728, 'magpsf': 15.278, 'sigmapsf': 0.061, 'filter': 'r'},
#   {'jd': 2459223.91595, 'magpsf': 16.388, 'sigmapsf': 0.068, 'filter': 'g'},
#   {'jd': 2459224.75417, 'magpsf': 15.442, 'sigmapsf': 0.101, 'filter': 'r'},
#   {'jd': 2459223.82662, 'magpsf': 16.331, 'sigmapsf': 0.041, 'filter': 'g'},
#   {'jd': 2459224.8006, 'magpsf': 15.283, 'sigmapsf': 0.074, 'filter': 'r'},
#   {'jd': 2459224.80887, 'magpsf': 15.413, 'sigmapsf': 0.07, 'filter': 'r'},
#   {'jd': 2459224.82884, 'magpsf': 16.308, 'sigmapsf': 0.045, 'filter': 'g'},
#   {'jd': 2459224.89312, 'magpsf': 15.366, 'sigmapsf': 0.041, 'filter': 'i'},
#   {'jd': 2459224.8098, 'magpsf': 15.431, 'sigmapsf': 0.057, 'filter': 'r'},
#   {'jd': 2459224.92264, 'magpsf': 16.269, 'sigmapsf': 0.043, 'filter': 'g'},
#   {'jd': 2459224.93266, 'magpsf': 16.28, 'sigmapsf': 0.04, 'filter': 'g'},
#   {'jd': 2459224.9336, 'magpsf': 16.361, 'sigmapsf': 0.043, 'filter': 'g'},
#   {'jd': 2459225.71772, 'magpsf': 16.32, 'sigmapsf': 0.045, 'filter': 'g'},
#   {'jd': 2459225.75891, 'magpsf': 15.43, 'sigmapsf': 0.052, 'filter': 'r'},
#   {'jd': 2459225.71865, 'magpsf': 16.251, 'sigmapsf': 0.042, 'filter': 'g'},
#   {'jd': 2459225.83693, 'magpsf': 16.144, 'sigmapsf': 0.077, 'filter': 'g'},
#   {'jd': 2459225.88228, 'magpsf': 15.245, 'sigmapsf': 0.044, 'filter': 'r'},
#   {'jd': 2459225.85676, 'magpsf': 15.442, 'sigmapsf': 0.068, 'filter': 'r'},
#   {'jd': 2459226.76392, 'magpsf': 15.477, 'sigmapsf': 0.069, 'filter': 'r'},
#   {'jd': 2459226.76579, 'magpsf': 15.326, 'sigmapsf': 0.048, 'filter': 'r'},
#   {'jd': 2459226.76485, 'magpsf': 15.325, 'sigmapsf': 0.054, 'filter': 'r'},
#   {'jd': 2459226.8058, 'magpsf': 16.257, 'sigmapsf': 0.022, 'filter': 'g'},
#   {'jd': 2459226.82417, 'magpsf': 16.302, 'sigmapsf': 0.055, 'filter': 'g'},
#   {'jd': 2459226.88867, 'magpsf': 16.305, 'sigmapsf': 0.052, 'filter': 'g'},
#   {'jd': 2459226.90677, 'magpsf': 15.322, 'sigmapsf': 0.061, 'filter': 'r'},
#   {'jd': 2459226.81071, 'magpsf': 16.208, 'sigmapsf': 0.051, 'filter': 'g'},
#   {'jd': 2459227.72443, 'magpsf': 16.298, 'sigmapsf': 0.078, 'filter': 'g'},
#   {'jd': 2459227.82413, 'magpsf': 15.479, 'sigmapsf': 0.078, 'filter': 'r'},
#   {'jd': 2459228.7809, 'magpsf': 16.042, 'sigmapsf': 0.113, 'filter': 'g'},
#   {'jd': 2459228.9016, 'magpsf': 16.081, 'sigmapsf': 0.103, 'filter': 'g'},
#   {'jd': 2459227.91374, 'magpsf': 15.065, 'sigmapsf': 0.113, 'filter': 'i'},
#   {'jd': 2459227.95414, 'magpsf': 16.187, 'sigmapsf': 0.086, 'filter': 'g'},
#   {'jd': 2459228.94928, 'magpsf': 15.208, 'sigmapsf': 0.079, 'filter': 'r'},
#   {'jd': 2459227.80872, 'magpsf': 15.309, 'sigmapsf': 0.136, 'filter': 'r'},
#   {'jd': 2459228.82729, 'magpsf': 15.396, 'sigmapsf': 0.015, 'filter': 'r'},
#   {'jd': 2459229.6991, 'magpsf': 16.314, 'sigmapsf': 0.044, 'filter': 'g'},
#   {'jd': 2459229.81617, 'magpsf': 16.157, 'sigmapsf': 0.036, 'filter': 'g'},
#   {'jd': 2459229.80295, 'magpsf': 16.268, 'sigmapsf': 0.046, 'filter': 'g'},
#   {'jd': 2459230.74263, 'magpsf': 15.496, 'sigmapsf': 0.044, 'filter': 'r'},
#   {'jd': 2459230.75736, 'magpsf': 15.434, 'sigmapsf': 0.088, 'filter': 'r'},
#   {'jd': 2459230.80738, 'magpsf': 15.958, 'sigmapsf': 0.08, 'filter': 'g'},
#   {'jd': 2459230.80932, 'magpsf': 16.003, 'sigmapsf': 0.078, 'filter': 'g'},
#   {'jd': 2459230.91146, 'magpsf': 16.169, 'sigmapsf': 0.092, 'filter': 'g'},
#   {'jd': 2459230.80832, 'magpsf': 15.947, 'sigmapsf': 0.064, 'filter': 'g'},
#   {'jd': 2459231.69845, 'magpsf': 15.479, 'sigmapsf': 0.05, 'filter': 'r'},
#   {'jd': 2459231.73606, 'magpsf': 16.161, 'sigmapsf': 0.057, 'filter': 'g'},
#   {'jd': 2459231.74523, 'magpsf': 16.195, 'sigmapsf': 0.074, 'filter': 'g'},
#   {'jd': 2459231.80611, 'magpsf': 15.227, 'sigmapsf': 0.094, 'filter': 'r'},
#   {'jd': 2459231.79848, 'magpsf': 15.401, 'sigmapsf': 0.075, 'filter': 'r'},
#   {'jd': 2459232.76031, 'magpsf': 16.216, 'sigmapsf': 0.075, 'filter': 'g'},
#   {'jd': 2459232.78094, 'magpsf': 16.167, 'sigmapsf': 0.1, 'filter': 'g'},
#   {'jd': 2459232.80659, 'magpsf': 15.235, 'sigmapsf': 0.08, 'filter': 'r'},
#   {'jd': 2459232.84759, 'magpsf': 15.418, 'sigmapsf': 0.06, 'filter': 'r'},
#   {'jd': 2459232.78193, 'magpsf': 16.216, 'sigmapsf': 0.084, 'filter': 'g'},
#   {'jd': 2459232.89356, 'magpsf': 16.244, 'sigmapsf': 0.056, 'filter': 'g'},
#   {'jd': 2459233.79012, 'magpsf': 15.547, 'sigmapsf': 0.066, 'filter': 'r'},
#   {'jd': 2459233.86505, 'magpsf': 16.471, 'sigmapsf': 0.088, 'filter': 'g'},
#   {'jd': 2459248.72472, 'magpsf': 16.485, 'sigmapsf': 0.092, 'filter': 'g'},
#   {'jd': 2459248.7431, 'magpsf': 15.366, 'sigmapsf': 0.08, 'filter': 'r'},
#   {'jd': 2459249.72262, 'magpsf': 16.517, 'sigmapsf': 0.076, 'filter': 'g'},
#   {'jd': 2459249.84182, 'magpsf': 15.363, 'sigmapsf': 0.044, 'filter': 'r'},
#   {'jd': 2459250.72705, 'magpsf': 15.063, 'sigmapsf': 0.053, 'filter': 'r'},
#   {'jd': 2459250.72799, 'magpsf': 15.035, 'sigmapsf': 0.059, 'filter': 'r'},
#   {'jd': 2459250.76378, 'magpsf': 15.893, 'sigmapsf': 0.038, 'filter': 'g'},
#   {'jd': 2459250.76472, 'magpsf': 15.915, 'sigmapsf': 0.048, 'filter': 'g'},
#   {'jd': 2459251.76399, 'magpsf': 16.449, 'sigmapsf': 0.131, 'filter': 'g'},
#   {'jd': 2459252.75723, 'magpsf': 16.518, 'sigmapsf': 0.028, 'filter': 'g'},
#   {'jd': 2459252.75817, 'magpsf': 16.293, 'sigmapsf': 0.123, 'filter': 'g'},
#   {'jd': 2459252.79094, 'magpsf': 15.372, 'sigmapsf': 0.078, 'filter': 'r'},
#   {'jd': 2459252.87336, 'magpsf': 15.523, 'sigmapsf': 0.117, 'filter': 'r'},
#   {'jd': 2459253.73806, 'magpsf': 15.899, 'sigmapsf': 0.066, 'filter': 'g'},
#   {'jd': 2459253.80117, 'magpsf': 15.149, 'sigmapsf': 0.012, 'filter': 'r'},
#   {'jd': 2459254.78558, 'magpsf': 16.284, 'sigmapsf': 0.068, 'filter': 'g'},
#   {'jd': 2459255.77859, 'magpsf': 15.43, 'sigmapsf': 0.072, 'filter': 'r'},
#   {'jd': 2459256.71833, 'magpsf': 15.203, 'sigmapsf': 0.013, 'filter': 'r'},
#   {'jd': 2459256.72406, 'magpsf': 15.015, 'sigmapsf': 0.06, 'filter': 'r'},
#   {'jd': 2459256.79167, 'magpsf': 15.88, 'sigmapsf': 0.045, 'filter': 'g'},
#   {'jd': 2459256.82571, 'magpsf': 15.963, 'sigmapsf': 0.045, 'filter': 'g'},
#   {'jd': 2459257.71786, 'magpsf': 15.357, 'sigmapsf': 0.104, 'filter': 'r'},
#   {'jd': 2459257.83019, 'magpsf': 16.299, 'sigmapsf': 0.076, 'filter': 'g'},
#   {'jd': 2459260.6949, 'magpsf': 16.261, 'sigmapsf': 0.053, 'filter': 'g'},
#   {'jd': 2459260.69583, 'magpsf': 16.205, 'sigmapsf': 0.071, 'filter': 'g'},
#   {'jd': 2459262.72348, 'magpsf': 15.054, 'sigmapsf': 0.059, 'filter': 'r'},
#   {'jd': 2459262.77993, 'magpsf': 15.957, 'sigmapsf': 0.045, 'filter': 'g'},
#   {'jd': 2459263.72264, 'magpsf': 15.219, 'sigmapsf': 0.049, 'filter': 'r'},
#   {'jd': 2459263.72506, 'magpsf': 15.316, 'sigmapsf': 0.054, 'filter': 'r'},
#   {'jd': 2459263.78083, 'magpsf': 16.123, 'sigmapsf': 0.073, 'filter': 'g'},
#   {'jd': 2459263.78178, 'magpsf': 16.225, 'sigmapsf': 0.05, 'filter': 'g'},
#   {'jd': 2459264.76803, 'magpsf': 16.352, 'sigmapsf': 0.092, 'filter': 'g'},
#   {'jd': 2459265.69836, 'magpsf': 15.954, 'sigmapsf': 0.065, 'filter': 'g'},
#   {'jd': 2459265.70142, 'magpsf': 15.927, 'sigmapsf': 0.084, 'filter': 'g'},
#   {'jd': 2459265.71443, 'magpsf': 15.177, 'sigmapsf': 0.078, 'filter': 'r'},
#   {'jd': 2459266.65297, 'magpsf': 16.227, 'sigmapsf': 0.046, 'filter': 'g'},
#   {'jd': 2459266.74749, 'magpsf': 15.326, 'sigmapsf': 0.045, 'filter': 'r'},
#   {'jd': 2459267.7711, 'magpsf': 15.512, 'sigmapsf': 0.092, 'filter': 'r'},
#   {'jd': 2459267.72752, 'magpsf': 16.574, 'sigmapsf': 0.064, 'filter': 'g'},
#   {'jd': 2459270.73536, 'magpsf': 16.617, 'sigmapsf': 0.114, 'filter': 'g'},
#   {'jd': 2459270.79862, 'magpsf': 16.062, 'sigmapsf': 0.122, 'filter': 'r'},
#   {'jd': 2459271.72015, 'magpsf': 16.03, 'sigmapsf': 0.046, 'filter': 'g'},
#   {'jd': 2459271.7612, 'magpsf': 15.321, 'sigmapsf': 0.057, 'filter': 'r'},
#   {'jd': 2459272.67759, 'magpsf': 16.131, 'sigmapsf': 0.039, 'filter': 'g'},
#   {'jd': 2459272.67853, 'magpsf': 16.09, 'sigmapsf': 0.048, 'filter': 'g'},
#   {'jd': 2459272.75514, 'magpsf': 15.294, 'sigmapsf': 0.044, 'filter': 'r'},
#   {'jd': 2459272.7541, 'magpsf': 15.327, 'sigmapsf': 0.041, 'filter': 'r'},
#   {'jd': 2459274.66427, 'magpsf': 16.348, 'sigmapsf': 0.043, 'filter': 'g'},
#   {'jd': 2459274.66332, 'magpsf': 16.252, 'sigmapsf': 0.049, 'filter': 'g'},
#   {'jd': 2459274.83786, 'magpsf': 15.29, 'sigmapsf': 0.04, 'filter': 'r'},
#   {'jd': 2459280.70235, 'magpsf': 16.254, 'sigmapsf': 0.1, 'filter': 'g'}],
#  'ZTF18abwqrhs': [],
#  'ZTF18abwsaid': [],
#  'ZTF18abxbmzg': [],
#  'ZTF18abxfdku': [],
#  'ZTF18abyittl': [],
#  'ZTF18acbbbak': [],
#  'ZTF18acbuxxu': [],
#  'ZTF18acbylwe': [],
#  'ZTF18acbzvqq': [],
#  'ZTF18accdgvb': [{'jd': 2459221.85801,
#    'magpsf': 19.357,
#    'sigmapsf': 0.143,
#    'filter': 'r'},
#   {'jd': 2459221.93493, 'magpsf': 19.353, 'sigmapsf': 0.115, 'filter': 'g'},
#   {'jd': 2459222.81946, 'magpsf': 19.378, 'sigmapsf': 0.124, 'filter': 'r'},
#   {'jd': 2459222.83214, 'magpsf': 19.382, 'sigmapsf': 0.12, 'filter': 'r'},
#   {'jd': 2459222.86067, 'magpsf': 19.326, 'sigmapsf': 0.098, 'filter': 'g'},
#   {'jd': 2459222.86161, 'magpsf': 19.35, 'sigmapsf': 0.119, 'filter': 'g'},
#   {'jd': 2459223.86042, 'magpsf': 19.398, 'sigmapsf': 0.123, 'filter': 'r'},
#   {'jd': 2459224.79589, 'magpsf': 19.394, 'sigmapsf': 0.177, 'filter': 'r'},
#   {'jd': 2459224.83837, 'magpsf': 19.323, 'sigmapsf': 0.123, 'filter': 'g'},
#   {'jd': 2459224.83929, 'magpsf': 19.34, 'sigmapsf': 0.115, 'filter': 'g'},
#   {'jd': 2459225.854, 'magpsf': 19.344, 'sigmapsf': 0.113, 'filter': 'g'},
#   {'jd': 2459225.86953, 'magpsf': 19.382, 'sigmapsf': 0.117, 'filter': 'r'},
#   {'jd': 2459226.78546, 'magpsf': 19.408, 'sigmapsf': 0.139, 'filter': 'r'},
#   {'jd': 2459226.81565, 'magpsf': 19.415, 'sigmapsf': 0.149, 'filter': 'g'},
#   {'jd': 2459228.83157, 'magpsf': 19.413, 'sigmapsf': 0.106, 'filter': 'r'},
#   {'jd': 2459228.86703, 'magpsf': 19.376, 'sigmapsf': 0.128, 'filter': 'g'},
#   {'jd': 2459226.78454, 'magpsf': 19.434, 'sigmapsf': 0.129, 'filter': 'r'},
#   {'jd': 2459226.8034, 'magpsf': 19.388, 'sigmapsf': 0.128, 'filter': 'g'},
#   {'jd': 2459227.81502, 'magpsf': 19.403, 'sigmapsf': 0.126, 'filter': 'r'},
#   {'jd': 2459227.83743, 'magpsf': 19.231, 'sigmapsf': 0.097, 'filter': 'g'},
#   {'jd': 2459228.79731, 'magpsf': 19.818, 'sigmapsf': 0.287, 'filter': 'i'},
#   {'jd': 2459228.81815, 'magpsf': 19.329, 'sigmapsf': 0.109, 'filter': 'r'},
#   {'jd': 2459228.86609, 'magpsf': 19.317, 'sigmapsf': 0.108, 'filter': 'g'},
#   {'jd': 2459229.8211, 'magpsf': 19.649, 'sigmapsf': 0.181, 'filter': 'g'},
#   {'jd': 2459230.79111, 'magpsf': 19.257, 'sigmapsf': 0.105, 'filter': 'r'},
#   {'jd': 2459230.79208, 'magpsf': 19.353, 'sigmapsf': 0.148, 'filter': 'r'},
#   {'jd': 2459230.83823, 'magpsf': 19.315, 'sigmapsf': 0.114, 'filter': 'g'},
#   {'jd': 2459230.83917, 'magpsf': 19.3, 'sigmapsf': 0.111, 'filter': 'g'},
#   {'jd': 2459231.75847, 'magpsf': 19.488, 'sigmapsf': 0.213, 'filter': 'g'},
#   {'jd': 2459232.78762, 'magpsf': 19.361, 'sigmapsf': 0.113, 'filter': 'g'},
#   {'jd': 2459231.8166, 'magpsf': 19.28, 'sigmapsf': 0.127, 'filter': 'r'},
#   {'jd': 2459232.78668, 'magpsf': 19.404, 'sigmapsf': 0.131, 'filter': 'g'},
#   {'jd': 2459232.87378, 'magpsf': 19.38, 'sigmapsf': 0.123, 'filter': 'r'},
#   {'jd': 2459232.87425, 'magpsf': 19.502, 'sigmapsf': 0.127, 'filter': 'r'},
#   {'jd': 2459248.74969, 'magpsf': 19.41, 'sigmapsf': 0.11, 'filter': 'r'},
#   {'jd': 2459248.76954, 'magpsf': 19.412, 'sigmapsf': 0.13, 'filter': 'g'},
#   {'jd': 2459250.75617, 'magpsf': 19.445, 'sigmapsf': 0.129, 'filter': 'g'},
#   {'jd': 2459233.75784, 'magpsf': 19.355, 'sigmapsf': 0.105, 'filter': 'r'},
#   {'jd': 2459233.8187, 'magpsf': 19.373, 'sigmapsf': 0.102, 'filter': 'g'},
#   {'jd': 2459248.74875, 'magpsf': 19.556, 'sigmapsf': 0.133, 'filter': 'r'},
#   {'jd': 2459248.7686, 'magpsf': 19.491, 'sigmapsf': 0.134, 'filter': 'g'},
#   {'jd': 2459249.79662, 'magpsf': 19.451, 'sigmapsf': 0.299, 'filter': 'r'},
#   {'jd': 2459250.71466, 'magpsf': 19.451, 'sigmapsf': 0.162, 'filter': 'r'},
#   {'jd': 2459250.75523, 'magpsf': 19.549, 'sigmapsf': 0.143, 'filter': 'g'},
#   {'jd': 2459250.828, 'magpsf': 19.487, 'sigmapsf': 0.16, 'filter': 'r'},
#   {'jd': 2459252.71266, 'magpsf': 19.304, 'sigmapsf': 0.096, 'filter': 'r'},
#   {'jd': 2459252.7867, 'magpsf': 19.417, 'sigmapsf': 0.118, 'filter': 'g'},
#   {'jd': 2459254.73098, 'magpsf': 19.298, 'sigmapsf': 0.119, 'filter': 'g'},
#   {'jd': 2459254.75373, 'magpsf': 19.377, 'sigmapsf': 0.119, 'filter': 'r'},
#   {'jd': 2459256.7117, 'magpsf': 19.494, 'sigmapsf': 0.122, 'filter': 'r'},
#   {'jd': 2459256.77512, 'magpsf': 19.456, 'sigmapsf': 0.139, 'filter': 'g'},
#   {'jd': 2459260.69159, 'magpsf': 19.413, 'sigmapsf': 0.133, 'filter': 'g'},
#   {'jd': 2459260.75046, 'magpsf': 19.509, 'sigmapsf': 0.14, 'filter': 'r'},
#   {'jd': 2459263.71326, 'magpsf': 19.528, 'sigmapsf': 0.217, 'filter': 'r'},
#   {'jd': 2459263.77641, 'magpsf': 19.441, 'sigmapsf': 0.246, 'filter': 'g'},
#   {'jd': 2459265.70435, 'magpsf': 19.464, 'sigmapsf': 0.116, 'filter': 'g'},
#   {'jd': 2459265.73278, 'magpsf': 19.496, 'sigmapsf': 0.153, 'filter': 'r'},
#   {'jd': 2459267.67403, 'magpsf': 19.559, 'sigmapsf': 0.192, 'filter': 'r'},
#   {'jd': 2459267.73476, 'magpsf': 19.391, 'sigmapsf': 0.154, 'filter': 'g'},
#   {'jd': 2459270.73214, 'magpsf': 19.223, 'sigmapsf': 0.221, 'filter': 'g'},
#   {'jd': 2459272.67137, 'magpsf': 19.535, 'sigmapsf': 0.287, 'filter': 'g'},
#   {'jd': 2459272.71181, 'magpsf': 19.542, 'sigmapsf': 0.254, 'filter': 'r'},
#   {'jd': 2459276.71069, 'magpsf': 19.687, 'sigmapsf': 0.125, 'filter': 'g'},
#   {'jd': 2459276.78003, 'magpsf': 19.483, 'sigmapsf': 0.13, 'filter': 'r'},
#   {'jd': 2459280.69072, 'magpsf': 19.449, 'sigmapsf': 0.124, 'filter': 'g'},
#   {'jd': 2459280.79046, 'magpsf': 19.484, 'sigmapsf': 0.118, 'filter': 'r'}],
#  'ZTF18accdimj': [{'jd': 2459221.75516,
#    'magpsf': 19.049,
#    'sigmapsf': 0.103,
#    'filter': 'r'},
#   {'jd': 2459221.75564, 'magpsf': 19.124, 'sigmapsf': 0.105, 'filter': 'r'},
#   {'jd': 2459221.76434, 'magpsf': 19.156, 'sigmapsf': 0.13, 'filter': 'r'},
#   {'jd': 2459221.80988, 'magpsf': 19.337, 'sigmapsf': 0.103, 'filter': 'g'},
#   {'jd': 2459221.81036, 'magpsf': 19.279, 'sigmapsf': 0.106, 'filter': 'g'},
#   {'jd': 2459221.81131, 'magpsf': 19.233, 'sigmapsf': 0.121, 'filter': 'g'},
#   {'jd': 2459221.85847, 'magpsf': 19.008, 'sigmapsf': 0.112, 'filter': 'r'},
#   {'jd': 2459221.85895, 'magpsf': 19.045, 'sigmapsf': 0.109, 'filter': 'r'},
#   {'jd': 2459221.88236, 'magpsf': 19.265, 'sigmapsf': 0.111, 'filter': 'g'},
#   {'jd': 2459221.88785, 'magpsf': 19.412, 'sigmapsf': 0.15, 'filter': 'g'},
#   {'jd': 2459221.88831, 'magpsf': 19.231, 'sigmapsf': 0.112, 'filter': 'g'},
#   {'jd': 2459221.91965, 'magpsf': 18.962, 'sigmapsf': 0.128, 'filter': 'r'},
#   {'jd': 2459222.75988, 'magpsf': 19.044, 'sigmapsf': 0.108, 'filter': 'r'},
#   {'jd': 2459222.76035, 'magpsf': 19.175, 'sigmapsf': 0.144, 'filter': 'r'},
#   {'jd': 2459222.8077, 'magpsf': 19.382, 'sigmapsf': 0.107, 'filter': 'g'},
#   {'jd': 2459222.83074, 'magpsf': 19.051, 'sigmapsf': 0.097, 'filter': 'r'},
#   {'jd': 2459222.83833, 'magpsf': 19.081, 'sigmapsf': 0.101, 'filter': 'r'},
#   {'jd': 2459222.8388, 'magpsf': 19.147, 'sigmapsf': 0.114, 'filter': 'r'},
#   {'jd': 2459222.83926, 'magpsf': 19.002, 'sigmapsf': 0.111, 'filter': 'r'},
#   {'jd': 2459222.85212, 'magpsf': 19.142, 'sigmapsf': 0.096, 'filter': 'r'},
#   {'jd': 2459222.88201, 'magpsf': 19.193, 'sigmapsf': 0.098, 'filter': 'g'},
#   {'jd': 2459222.83973, 'magpsf': 19.067, 'sigmapsf': 0.105, 'filter': 'r'},
#   {'jd': 2459222.88295, 'magpsf': 19.191, 'sigmapsf': 0.092, 'filter': 'g'},
#   {'jd': 2459222.91346, 'magpsf': 19.23, 'sigmapsf': 0.119, 'filter': 'g'},
#   {'jd': 2459222.91394, 'magpsf': 19.298, 'sigmapsf': 0.102, 'filter': 'g'},
#   {'jd': 2459222.9144, 'magpsf': 19.312, 'sigmapsf': 0.167, 'filter': 'g'},
#   {'jd': 2459222.91487, 'magpsf': 19.312, 'sigmapsf': 0.099, 'filter': 'g'},
# ...
#   {'jd': 2459229.94118, 'magpsf': 19.248, 'sigmapsf': 0.14, 'filter': 'g'},
#   {'jd': 2459230.75831, 'magpsf': 18.986, 'sigmapsf': 0.108, 'filter': 'r'},
#   {'jd': 2459230.78877, 'magpsf': 18.978, 'sigmapsf': 0.082, 'filter': 'r'},
#   {'jd': 2459230.81249, 'magpsf': 19.195, 'sigmapsf': 0.094, 'filter': 'g'},
#   {'jd': 2459230.90376, 'magpsf': 19.193, 'sigmapsf': 0.104, 'filter': 'g'},
#   {'jd': 2459230.9138, 'magpsf': 19.191, 'sigmapsf': 0.096, 'filter': 'g'},
#   {'jd': 2459230.95601, 'magpsf': 19.042, 'sigmapsf': 0.091, 'filter': 'r'},
#   {'jd': 2459231.75987, 'magpsf': 19.166, 'sigmapsf': 0.12, 'filter': 'g'},
#   {'jd': 2459231.80803, 'magpsf': 19.005, 'sigmapsf': 0.101, 'filter': 'r'},
#   {'jd': 2459231.85868, 'magpsf': 19.038, 'sigmapsf': 0.102, 'filter': 'r'},
#   {'jd': 2459232.75793, 'magpsf': 19.215, 'sigmapsf': 0.12, 'filter': 'g'},
#   {'jd': 2459232.79986, 'magpsf': 19.12, 'sigmapsf': 0.073, 'filter': 'r'},
#   {'jd': 2459232.82882, 'magpsf': 19.047, 'sigmapsf': 0.103, 'filter': 'r'},
#   {'jd': 2459232.84999, 'magpsf': 19.064, 'sigmapsf': 0.075, 'filter': 'r'},
#   {'jd': 2459232.88385, 'magpsf': 19.138, 'sigmapsf': 0.093, 'filter': 'g'},
#   {'jd': 2459232.89499, 'magpsf': 19.206, 'sigmapsf': 0.08, 'filter': 'g'},
#   {'jd': 2459233.75928, 'magpsf': 18.985, 'sigmapsf': 0.109, 'filter': 'r'},
#   {'jd': 2459248.72808, 'magpsf': 19.214, 'sigmapsf': 0.096, 'filter': 'g'},
#   {'jd': 2459248.74688, 'magpsf': 19.066, 'sigmapsf': 0.102, 'filter': 'r'},
#   {'jd': 2459250.72943, 'magpsf': 19.125, 'sigmapsf': 0.095, 'filter': 'r'},
#   {'jd': 2459250.7609, 'magpsf': 19.254, 'sigmapsf': 0.101, 'filter': 'g'},
#   {'jd': 2459252.70385, 'magpsf': 19.063, 'sigmapsf': 0.081, 'filter': 'r'},
#   {'jd': 2459252.76686, 'magpsf': 19.319, 'sigmapsf': 0.091, 'filter': 'g'},
#   {'jd': 2459254.69565, 'magpsf': 19.101, 'sigmapsf': 0.087, 'filter': 'r'},
#   {'jd': 2459254.72748, 'magpsf': 19.253, 'sigmapsf': 0.075, 'filter': 'g'},
#   {'jd': 2459256.71406, 'magpsf': 19.062, 'sigmapsf': 0.101, 'filter': 'r'},
#   {'jd': 2459256.79586, 'magpsf': 19.277, 'sigmapsf': 0.106, 'filter': 'g'},
#   {'jd': 2459260.69299, 'magpsf': 19.252, 'sigmapsf': 0.166, 'filter': 'g'},
#   {'jd': 2459260.75346, 'magpsf': 19.095, 'sigmapsf': 0.09, 'filter': 'r'},
#   {'jd': 2459263.73481, 'magpsf': 18.99, 'sigmapsf': 0.106, 'filter': 'r'},
#   {'jd': 2459263.77734, 'magpsf': 19.381, 'sigmapsf': 0.127, 'filter': 'g'},
#   {'jd': 2459265.73372, 'magpsf': 19.108, 'sigmapsf': 0.1, 'filter': 'r'},
#   {'jd': 2459265.89164, 'magpsf': 19.331, 'sigmapsf': 0.135, 'filter': 'g'},
#   {'jd': 2459267.67544, 'magpsf': 19.05, 'sigmapsf': 0.121, 'filter': 'r'},
#   {'jd': 2459267.77711, 'magpsf': 19.249, 'sigmapsf': 0.131, 'filter': 'g'},
#   {'jd': 2459271.72688, 'magpsf': 19.239, 'sigmapsf': 0.217, 'filter': 'g'},
#   {'jd': 2459271.73644, 'magpsf': 19.029, 'sigmapsf': 0.12, 'filter': 'r'},
#   {'jd': 2459273.67439, 'magpsf': 19.356, 'sigmapsf': 0.165, 'filter': 'g'},
#   {'jd': 2459273.71309, 'magpsf': 19.044, 'sigmapsf': 0.154, 'filter': 'r'},
#   {'jd': 2459275.67304, 'magpsf': 19.238, 'sigmapsf': 0.099, 'filter': 'g'},
#   {'jd': 2459275.77878, 'magpsf': 19.048, 'sigmapsf': 0.103, 'filter': 'r'},
#   {'jd': 2459278.685, 'magpsf': 19.012, 'sigmapsf': 0.108, 'filter': 'r'},
#   {'jd': 2459278.71326, 'magpsf': 19.124, 'sigmapsf': 0.13, 'filter': 'g'}],
#  'ZTF18aagpqdj': [{'jd': 2459222.94743,
#    'magpsf': 19.572,
#    'sigmapsf': 0.242,
#    'filter': 'r'},
#   {'jd': 2459223.87418, 'magpsf': 19.468, 'sigmapsf': 0.232, 'filter': 'r'}],
#  'ZTF18aagread': [],
#  'ZTF18aagrivy': [],
#  'ZTF18aagrlip': [],
#  'ZTF18aahsaha': [],
#  'ZTF18aahsylr': [],
#  'ZTF18aaicqsl': [],
#  'ZTF18aajbsgf': [],
#  'ZTF18aajhiec': [],
#  'ZTF18aajlmud': [],
#  'ZTF18aajoshd': [],
#  'ZTF18aajsauz': [],
#  'ZTF18aajxnra': [],
#  'ZTF18aakdfgg': [],
#  'ZTF18aakvuwy': [],
#  'ZTF18aankkrr': [],
#  'ZTF18aanuqmi': [],
#  'ZTF18aaotzkw': [],
#  'ZTF18aaptdbi': [],
#  'ZTF18aaqjedb': [{'jd': 2459221.75516,
#    'magpsf': 18.575,
#    'sigmapsf': 0.077,
#    'filter': 'r'},
#   {'jd': 2459221.81131, 'magpsf': 18.947, 'sigmapsf': 0.077, 'filter': 'g'},
#   {'jd': 2459221.85847, 'magpsf': 18.577, 'sigmapsf': 0.063, 'filter': 'r'},
#   {'jd': 2459221.88236, 'magpsf': 18.854, 'sigmapsf': 0.101, 'filter': 'g'},
#   {'jd': 2459222.75988, 'magpsf': 18.594, 'sigmapsf': 0.076, 'filter': 'r'},
#   {'jd': 2459222.83926, 'magpsf': 18.536, 'sigmapsf': 0.074, 'filter': 'r'},
#   {'jd': 2459222.83833, 'magpsf': 18.574, 'sigmapsf': 0.072, 'filter': 'r'},
#   {'jd': 2459222.88201, 'magpsf': 18.867, 'sigmapsf': 0.104, 'filter': 'g'},
#   {'jd': 2459222.92392, 'magpsf': 19.301, 'sigmapsf': 0.186, 'filter': 'i'},
#   {'jd': 2459222.95876, 'magpsf': 18.847, 'sigmapsf': 0.1, 'filter': 'g'},
#   {'jd': 2459223.7742, 'magpsf': 18.529, 'sigmapsf': 0.077, 'filter': 'r'},
#   {'jd': 2459223.8233, 'magpsf': 18.887, 'sigmapsf': 0.082, 'filter': 'g'},
#   {'jd': 2459223.85947, 'magpsf': 18.501, 'sigmapsf': 0.071, 'filter': 'r'},
#   {'jd': 2459224.7362, 'magpsf': 18.701, 'sigmapsf': 0.111, 'filter': 'r'},
#   {'jd': 2459224.78916, 'magpsf': 18.561, 'sigmapsf': 0.075, 'filter': 'r'},
#   {'jd': 2459224.81218, 'magpsf': 18.599, 'sigmapsf': 0.073, 'filter': 'r'},
#   {'jd': 2459224.8335, 'magpsf': 18.839, 'sigmapsf': 0.091, 'filter': 'g'},
#   {'jd': 2459225.72723, 'magpsf': 18.931, 'sigmapsf': 0.103, 'filter': 'g'},
#   {'jd': 2459225.78416, 'magpsf': 18.603, 'sigmapsf': 0.078, 'filter': 'r'},
#   {'jd': 2459225.81917, 'magpsf': 19.188, 'sigmapsf': 0.127, 'filter': 'i'},
#   {'jd': 2459225.85353, 'magpsf': 18.933, 'sigmapsf': 0.094, 'filter': 'g'},
#   {'jd': 2459225.86906, 'magpsf': 18.583, 'sigmapsf': 0.074, 'filter': 'r'},
#   {'jd': 2459226.78406, 'magpsf': 18.672, 'sigmapsf': 0.081, 'filter': 'r'},
#   {'jd': 2459226.80387, 'magpsf': 18.995, 'sigmapsf': 0.109, 'filter': 'g'},
#   {'jd': 2459226.84894, 'magpsf': 18.963, 'sigmapsf': 0.136, 'filter': 'g'},
#   {'jd': 2459226.88586, 'magpsf': 18.896, 'sigmapsf': 0.089, 'filter': 'g'},
#   {'jd': 2459226.89968, 'magpsf': 18.568, 'sigmapsf': 0.068, 'filter': 'r'},
#   {'jd': 2459226.90824, 'magpsf': 18.601, 'sigmapsf': 0.09, 'filter': 'r'},
#   {'jd': 2459227.69711, 'magpsf': 18.968, 'sigmapsf': 0.092, 'filter': 'g'},
#   {'jd': 2459227.78341, 'magpsf': 18.551, 'sigmapsf': 0.077, 'filter': 'r'},
#   {'jd': 2459228.74674, 'magpsf': 18.541, 'sigmapsf': 0.068, 'filter': 'r'},
#   {'jd': 2459228.77763, 'magpsf': 18.986, 'sigmapsf': 0.105, 'filter': 'g'},
#   {'jd': 2459228.78719, 'magpsf': 18.906, 'sigmapsf': 0.075, 'filter': 'g'},
#   {'jd': 2459228.79824, 'magpsf': 19.253, 'sigmapsf': 0.169, 'filter': 'i'},
#   {'jd': 2459228.8191, 'magpsf': 18.666, 'sigmapsf': 0.077, 'filter': 'r'},
#   {'jd': 2459228.82003, 'magpsf': 18.575, 'sigmapsf': 0.065, 'filter': 'r'},
#   {'jd': 2459228.90308, 'magpsf': 18.991, 'sigmapsf': 0.114, 'filter': 'g'},
#   {'jd': 2459228.91404, 'magpsf': 18.963, 'sigmapsf': 0.093, 'filter': 'g'},
#   {'jd': 2459227.863, 'magpsf': 18.543, 'sigmapsf': 0.078, 'filter': 'r'},
#   {'jd': 2459227.92205, 'magpsf': 18.865, 'sigmapsf': 0.082, 'filter': 'g'},
#   {'jd': 2459229.75757, 'magpsf': 18.701, 'sigmapsf': 0.151, 'filter': 'r'},
#   {'jd': 2459229.8001, 'magpsf': 19.017, 'sigmapsf': 0.129, 'filter': 'g'},
#   {'jd': 2459229.87544, 'magpsf': 18.93, 'sigmapsf': 0.114, 'filter': 'g'},
#   {'jd': 2459229.91914, 'magpsf': 18.553, 'sigmapsf': 0.095, 'filter': 'r'},
#   {'jd': 2459230.75877, 'magpsf': 18.587, 'sigmapsf': 0.067, 'filter': 'r'},
#   {'jd': 2459230.75971, 'magpsf': 18.606, 'sigmapsf': 0.068, 'filter': 'r'},
#   {'jd': 2459230.83869, 'magpsf': 18.901, 'sigmapsf': 0.1, 'filter': 'g'},
#   {'jd': 2459230.84655, 'magpsf': 18.913, 'sigmapsf': 0.099, 'filter': 'g'},
#   {'jd': 2459230.85722, 'magpsf': 18.958, 'sigmapsf': 0.101, 'filter': 'g'},
#   {'jd': 2459230.93363, 'magpsf': 18.669, 'sigmapsf': 0.087, 'filter': 'r'},
#   {'jd': 2459231.75941, 'magpsf': 19.017, 'sigmapsf': 0.118, 'filter': 'g'},
#   {'jd': 2459231.80897, 'magpsf': 18.578, 'sigmapsf': 0.081, 'filter': 'r'},
#   {'jd': 2459231.83848, 'magpsf': 18.994, 'sigmapsf': 0.14, 'filter': 'i'},
#   {'jd': 2459231.85822, 'magpsf': 18.618, 'sigmapsf': 0.077, 'filter': 'r'},
#   {'jd': 2459231.87907, 'magpsf': 18.774, 'sigmapsf': 0.088, 'filter': 'g'},
#   {'jd': 2459232.76777, 'magpsf': 18.907, 'sigmapsf': 0.072, 'filter': 'g'},
#   {'jd': 2459232.79845, 'magpsf': 18.571, 'sigmapsf': 0.075, 'filter': 'r'},
#   {'jd': 2459232.84953, 'magpsf': 18.613, 'sigmapsf': 0.068, 'filter': 'r'},
#   {'jd': 2459232.87331, 'magpsf': 18.607, 'sigmapsf': 0.066, 'filter': 'r'},
#   {'jd': 2459232.88339, 'magpsf': 18.806, 'sigmapsf': 0.107, 'filter': 'g'},
#   {'jd': 2459232.89546, 'magpsf': 18.828, 'sigmapsf': 0.09, 'filter': 'g'},
#   {'jd': 2459233.71556, 'magpsf': 18.622, 'sigmapsf': 0.072, 'filter': 'r'},
#   {'jd': 2459233.7788, 'magpsf': 18.612, 'sigmapsf': 0.073, 'filter': 'r'},
#   {'jd': 2459248.72902, 'magpsf': 19.076, 'sigmapsf': 0.101, 'filter': 'g'},
#   {'jd': 2459248.73642, 'magpsf': 18.669, 'sigmapsf': 0.06, 'filter': 'r'},
#   {'jd': 2459233.86269, 'magpsf': 18.925, 'sigmapsf': 0.127, 'filter': 'g'},
#   {'jd': 2459250.75713, 'magpsf': 19.102, 'sigmapsf': 0.123, 'filter': 'g'},
#   {'jd': 2459250.82753, 'magpsf': 18.658, 'sigmapsf': 0.126, 'filter': 'r'},
#   {'jd': 2459252.70479, 'magpsf': 18.672, 'sigmapsf': 0.071, 'filter': 'r'},
#   {'jd': 2459252.76876, 'magpsf': 19.087, 'sigmapsf': 0.107, 'filter': 'g'},
#   {'jd': 2459254.69612, 'magpsf': 18.741, 'sigmapsf': 0.076, 'filter': 'r'},
#   {'jd': 2459251.73566, 'magpsf': 19.388, 'sigmapsf': 0.186, 'filter': 'i'},
#   {'jd': 2459254.72843, 'magpsf': 18.942, 'sigmapsf': 0.077, 'filter': 'g'},
#   {'jd': 2459256.71264, 'magpsf': 18.664, 'sigmapsf': 0.075, 'filter': 'r'},
#   {'jd': 2459254.82134, 'magpsf': 19.459, 'sigmapsf': 0.166, 'filter': 'i'},
#   {'jd': 2459256.77465, 'magpsf': 19.026, 'sigmapsf': 0.1, 'filter': 'g'},
#   {'jd': 2459260.69206, 'magpsf': 19.029, 'sigmapsf': 0.092, 'filter': 'g'},
#   {'jd': 2459257.80714, 'magpsf': 19.439, 'sigmapsf': 0.208, 'filter': 'i'},
#   {'jd': 2459260.7495, 'magpsf': 18.691, 'sigmapsf': 0.082, 'filter': 'r'},
#   {'jd': 2459263.73338, 'magpsf': 18.675, 'sigmapsf': 0.118, 'filter': 'r'},
#   {'jd': 2459263.77687, 'magpsf': 18.874, 'sigmapsf': 0.155, 'filter': 'g'},
#   {'jd': 2459265.70294, 'magpsf': 18.997, 'sigmapsf': 0.093, 'filter': 'g'},
#   {'jd': 2459262.75552, 'magpsf': 19.301, 'sigmapsf': 0.195, 'filter': 'i'},
#   {'jd': 2459265.73325, 'magpsf': 18.772, 'sigmapsf': 0.075, 'filter': 'r'},
#   {'jd': 2459267.6745, 'magpsf': 18.666, 'sigmapsf': 0.09, 'filter': 'r'},
#   {'jd': 2459267.73523, 'magpsf': 18.851, 'sigmapsf': 0.111, 'filter': 'g'},
#   {'jd': 2459271.72591, 'magpsf': 18.997, 'sigmapsf': 0.147, 'filter': 'g'},
#   {'jd': 2459271.73597, 'magpsf': 18.699, 'sigmapsf': 0.083, 'filter': 'r'},
#   {'jd': 2459273.67297, 'magpsf': 19.013, 'sigmapsf': 0.178, 'filter': 'g'},
#   {'jd': 2459273.71262, 'magpsf': 18.556, 'sigmapsf': 0.126, 'filter': 'r'},
#   {'jd': 2459275.67163, 'magpsf': 19.01, 'sigmapsf': 0.078, 'filter': 'g'},
#   {'jd': 2459275.73356, 'magpsf': 18.747, 'sigmapsf': 0.084, 'filter': 'r'},
#   {'jd': 2459278.68641, 'magpsf': 18.686, 'sigmapsf': 0.08, 'filter': 'r'},
#   {'jd': 2459278.71373, 'magpsf': 19.083, 'sigmapsf': 0.14, 'filter': 'g'}],
#  'ZTF18aaqzcja': [{'jd': 2459224.00814,
#    'magpsf': 19.579,
#    'sigmapsf': 0.341,
#    'filter': 'r'},
#   {'jd': 2459224.05547, 'magpsf': 19.431, 'sigmapsf': 0.161, 'filter': 'g'},
#   {'jd': 2459224.05645, 'magpsf': 19.511, 'sigmapsf': 0.155, 'filter': 'g'},
#   {'jd': 2459227.00895, 'magpsf': 19.565, 'sigmapsf': 0.188, 'filter': 'r'},
#   {'jd': 2459225.05042, 'magpsf': 19.557, 'sigmapsf': 0.17, 'filter': 'g'},
#   {'jd': 2459227.00988, 'magpsf': 19.742, 'sigmapsf': 0.233, 'filter': 'r'},
#   {'jd': 2459227.03309, 'magpsf': 19.541, 'sigmapsf': 0.143, 'filter': 'g'},
#   {'jd': 2459229.01153, 'magpsf': 19.596, 'sigmapsf': 0.149, 'filter': 'g'},
#   {'jd': 2459227.03403, 'magpsf': 19.646, 'sigmapsf': 0.155, 'filter': 'g'},
#   {'jd': 2459230.99403, 'magpsf': 19.529, 'sigmapsf': 0.151, 'filter': 'g'},
#   {'jd': 2459230.99497, 'magpsf': 19.674, 'sigmapsf': 0.183, 'filter': 'g'},
#   {'jd': 2459232.99269, 'magpsf': 19.812, 'sigmapsf': 0.202, 'filter': 'r'},
#   {'jd': 2459232.99175, 'magpsf': 19.849, 'sigmapsf': 0.212, 'filter': 'r'},
#   {'jd': 2459233.0339, 'magpsf': 19.474, 'sigmapsf': 0.115, 'filter': 'g'},
#   {'jd': 2459233.03484, 'magpsf': 19.6, 'sigmapsf': 0.151, 'filter': 'g'},
#   {'jd': 2459234.00014, 'magpsf': 19.756, 'sigmapsf': 0.185, 'filter': 'r'},
#   {'jd': 2459248.99131, 'magpsf': 19.616, 'sigmapsf': 0.167, 'filter': 'g'},
#   {'jd': 2459249.99638, 'magpsf': 19.9, 'sigmapsf': 0.239, 'filter': 'r'},
#   {'jd': 2459249.99731, 'magpsf': 19.853, 'sigmapsf': 0.195, 'filter': 'r'},
#   {'jd': 2459250.03575, 'magpsf': 19.594, 'sigmapsf': 0.158, 'filter': 'g'},
#   {'jd': 2459250.03669, 'magpsf': 19.57, 'sigmapsf': 0.136, 'filter': 'g'},
#   {'jd': 2459250.99297, 'magpsf': 19.53, 'sigmapsf': 0.156, 'filter': 'g'},
#   {'jd': 2459251.03506, 'magpsf': 19.808, 'sigmapsf': 0.196, 'filter': 'r'},
#   {'jd': 2459252.0324, 'magpsf': 19.453, 'sigmapsf': 0.162, 'filter': 'g'},
#   {'jd': 2459252.03436, 'magpsf': 19.597, 'sigmapsf': 0.133, 'filter': 'g'},
#   {'jd': 2459251.99672, 'magpsf': 19.896, 'sigmapsf': 0.277, 'filter': 'r'},
#   {'jd': 2459254.0364, 'magpsf': 19.643, 'sigmapsf': 0.133, 'filter': 'g'},
#   {'jd': 2459255.93168, 'magpsf': 19.795, 'sigmapsf': 0.149, 'filter': 'r'},
#   {'jd': 2459251.99433, 'magpsf': 19.793, 'sigmapsf': 0.246, 'filter': 'r'},
#   {'jd': 2459251.99528, 'magpsf': 19.686, 'sigmapsf': 0.201, 'filter': 'r'},
#   {'jd': 2459252.0353, 'magpsf': 19.565, 'sigmapsf': 0.169, 'filter': 'g'},
#   {'jd': 2459256.03568, 'magpsf': 19.549, 'sigmapsf': 0.146, 'filter': 'g'},
#   {'jd': 2459256.93318, 'magpsf': 19.617, 'sigmapsf': 0.125, 'filter': 'r'},
#   {'jd': 2459256.93127, 'magpsf': 19.704, 'sigmapsf': 0.163, 'filter': 'r'},
#   {'jd': 2459257.01398, 'magpsf': 19.52, 'sigmapsf': 0.131, 'filter': 'g'},
#   {'jd': 2459257.01492, 'magpsf': 19.553, 'sigmapsf': 0.121, 'filter': 'g'},
#   {'jd': 2459259.01385, 'magpsf': 19.434, 'sigmapsf': 0.128, 'filter': 'g'},
#   {'jd': 2459262.98957, 'magpsf': 19.6, 'sigmapsf': 0.155, 'filter': 'r'},
#   {'jd': 2459263.03478, 'magpsf': 19.603, 'sigmapsf': 0.159, 'filter': 'g'},
#   {'jd': 2459265.93061, 'magpsf': 19.712, 'sigmapsf': 0.212, 'filter': 'g'},
#   {'jd': 2459266.03142, 'magpsf': 19.809, 'sigmapsf': 0.165, 'filter': 'r'},
#   {'jd': 2459259.01286, 'magpsf': 19.339, 'sigmapsf': 0.178, 'filter': 'g'},
#   {'jd': 2459268.03466, 'magpsf': 19.582, 'sigmapsf': 0.144, 'filter': 'g'},
#   {'jd': 2459269.88762, 'magpsf': 19.834, 'sigmapsf': 0.193, 'filter': 'r'},
#   {'jd': 2459269.01547, 'magpsf': 19.714, 'sigmapsf': 0.134, 'filter': 'g'},
#   {'jd': 2459269.01641, 'magpsf': 19.648, 'sigmapsf': 0.133, 'filter': 'g'},
#   {'jd': 2459269.99106, 'magpsf': 19.637, 'sigmapsf': 0.209, 'filter': 'g'},
#   {'jd': 2459269.992, 'magpsf': 19.64, 'sigmapsf': 0.137, 'filter': 'g'},
#   {'jd': 2459269.99446, 'magpsf': 19.603, 'sigmapsf': 0.202, 'filter': 'g'},
#   {'jd': 2459270.93377, 'magpsf': 19.705, 'sigmapsf': 0.251, 'filter': 'g'},
#   {'jd': 2459273.97352, 'magpsf': 19.73, 'sigmapsf': 0.324, 'filter': 'r'},
#   {'jd': 2459274.97344, 'magpsf': 19.394, 'sigmapsf': 0.293, 'filter': 'g'},
#   {'jd': 2459275.97279, 'magpsf': 19.529, 'sigmapsf': 0.211, 'filter': 'g'},
#   {'jd': 2459276.00935, 'magpsf': 19.955, 'sigmapsf': 0.227, 'filter': 'r'},
#   {'jd': 2459276.99942, 'magpsf': 19.734, 'sigmapsf': 0.184, 'filter': 'r'},
#   {'jd': 2459277.01681, 'magpsf': 19.435, 'sigmapsf': 0.155, 'filter': 'g'},
#   {'jd': 2459278.9956, 'magpsf': 19.948, 'sigmapsf': 0.243, 'filter': 'r'},
#   {'jd': 2459278.99654, 'magpsf': 19.906, 'sigmapsf': 0.245, 'filter': 'r'},
#   {'jd': 2459279.01645, 'magpsf': 19.563, 'sigmapsf': 0.139, 'filter': 'g'},
#   {'jd': 2459279.02031, 'magpsf': 19.469, 'sigmapsf': 0.154, 'filter': 'g'}],
#  'ZTF18aatezdb': [{'jd': 2459248.97731,
#    'magpsf': 19.752,
#    'sigmapsf': 0.196,
#    'filter': 'g'},
#   {'jd': 2459250.93184, 'magpsf': 20.001, 'sigmapsf': 0.19, 'filter': 'r'}],
#  'ZTF18aavrkvy': [],
#  'ZTF18aaxcnxd': [],
#  ...}

# %% [markdown]
# What do the data look like? It is a good idea to see what the data variables include, but we have to be careful about printing such a large amount of information all at once. Exploring the length of what we are going to print first is racommended.

# %%
# How many alerts do we have?
len(df_alerts)
# Out:
# 106560

# %%
# What is the name of the alerts data frame columns?
df_alerts.columns
# Out:
# Index(['jd', 'fid', 'isdiffpos', 'rcid', 'ra', 'dec', 'magpsf', 'sigmapsf',
#        'rb', 'ssdistnr', 'srmag1', 'sgscore1', 'distpsnr1', 'ndethist',
#        'jdstarthist', 'jdendhist', 'srmag2', 'sgscore2', 'distpsnr2', 'srmag3',
#        'sgscore3', 'distpsnr3', 'drb', 'objectId'],
#       dtype='object')

# %% [markdown]
# **STOP**. What do these column names mean? In order to use them in a smart way, check them out in the [ZTF Avro schema](https://zwickytransientfacility.github.io/ztf-avro-alert/schema.html)

# %%
#What do alerts look like, in this short version?
df_alerts[0:3]
# Out:
#                                       jd fid isdiffpos rcid         ra  \
# 601cb75947230767c903ce48  2459250.626065   1         t   45  41.706031
# 601cb758040c9a45b915243b  2459250.626065   1         t   52   46.59873
# 601cb761da8192014092f81a  2459250.626065   1         t    4   46.82753
#
#                                 dec     magpsf  sigmapsf        rb ssdistnr  \
# 601cb75947230767c903ce48 -22.509571  15.914849  0.052548  0.512857   -999.0
# 601cb758040c9a45b915243b -20.729952  19.315357  0.187526  0.528571   -999.0
# 601cb761da8192014092f81a -27.066677  19.544296  0.215844  0.545714   -999.0
#
#                           ...     jdstarthist       jdendhist   srmag2  \
# 601cb75947230767c903ce48  ...  2458383.932454  2459250.626065  18.7122
# 601cb758040c9a45b915243b  ...  2458860.605127  2459250.626065  21.7882
# 601cb761da8192014092f81a  ...  2459117.897257  2459250.626065  20.7647
#
#                           sgscore2  distpsnr2     srmag3  sgscore3  distpsnr3  \
# 601cb75947230767c903ce48       1.0  11.778825     -999.0       0.5   15.36731
# 601cb758040c9a45b915243b  0.906845   5.796002  21.646299  0.923917  13.633864
# 601cb761da8192014092f81a     0.005   23.80216     -999.0    -999.0     -999.0
#
#                                drb      objectId
# 601cb75947230767c903ce48  0.975172  ZTF18abyitqr
# 601cb758040c9a45b915243b  0.999086  ZTF20aafuwfv
# 601cb761da8192014092f81a  0.988304  ZTF20acekgfz
#
# [3 rows x 24 columns]

# %% [markdown]
# Let's warm up with selection criteria for the alerts. For example, we can check if any one of the alerts has exactly 20 detections in its history, it is at least 5 arcsec away from the closest PS1 catalog source, and the closest PS1 cataloged source is likely a galaxy. Remember that the star/galaxy classification goes from 0 (likely galaxy) to 1 (likely star).

# %%
crit_test = (df_alerts['ndethist'] == 20) & (df_alerts['distpsnr1'] > 5) & (df_alerts['sgscore1'] < 0.5)
df_alerts[crit_test]["objectId"]
# Out:
# 601cfaac6fbae9e71c9bcabe    ZTF21aagnvvk
# 601d038d6fbae9e71c9bd805    ZTF21aagmryd
# Name: objectId, dtype: object

# %% [markdown]
# Let's display a light curve. For example, the dataset includes ZTF21aagnvvk, which is a Type Ia supernova that was assigned IAU name [AT2021bnf](https://www.wis-tns.org/object/2021bnf). You should have found this transient using the selection criteria in the cell above.
#
# To make things easier, the filter id (`fid`) column was replaced with the `filter` name (g, r, or i) column. Note that upper limits from non-detections are not included in this data set, so you will find only information about detections, even if knowing the last non-detection time of a transient can be crucial to constrain its onset.

# %%
lc_dict["ZTF21aagnvvk"]
# Out:
# [{'jd': 2459232.78481, 'magpsf': 20.856, 'sigmapsf': 0.371, 'filter': 'g'},
#  {'jd': 2459232.88103, 'magpsf': 20.705, 'sigmapsf': 0.269, 'filter': 'g'},
#  {'jd': 2459232.92484, 'magpsf': 20.591, 'sigmapsf': 0.286, 'filter': 'g'},
#  {'jd': 2459233.77119, 'magpsf': 20.487, 'sigmapsf': 0.273, 'filter': 'r'},
#  {'jd': 2459248.75645, 'magpsf': 19.06, 'sigmapsf': 0.11, 'filter': 'g'},
#  {'jd': 2459248.76622, 'magpsf': 19.032, 'sigmapsf': 0.09, 'filter': 'g'},
#  {'jd': 2459248.75551, 'magpsf': 19.082, 'sigmapsf': 0.104, 'filter': 'g'},
#  {'jd': 2459248.86705, 'magpsf': 18.948, 'sigmapsf': 0.104, 'filter': 'r'},
#  {'jd': 2459248.88325, 'magpsf': 18.924, 'sigmapsf': 0.094, 'filter': 'r'},
#  {'jd': 2459248.90036, 'magpsf': 19.016, 'sigmapsf': 0.113, 'filter': 'g'},
#  {'jd': 2459248.88231, 'magpsf': 19.025, 'sigmapsf': 0.094, 'filter': 'r'},
#  {'jd': 2459248.93757, 'magpsf': 19.023, 'sigmapsf': 0.11, 'filter': 'r'},
#  {'jd': 2459249.79897, 'magpsf': 19.158, 'sigmapsf': 0.28, 'filter': 'r'},
#  {'jd': 2459249.88734, 'magpsf': 18.997, 'sigmapsf': 0.157, 'filter': 'r'},
#  {'jd': 2459250.7448, 'magpsf': 19.049, 'sigmapsf': 0.157, 'filter': 'r'},
#  {'jd': 2459249.83978, 'magpsf': 19.016, 'sigmapsf': 0.151, 'filter': 'r'},
#  {'jd': 2459250.77574, 'magpsf': 19.082, 'sigmapsf': 0.121, 'filter': 'g'},
#  {'jd': 2459250.79469, 'magpsf': 19.041, 'sigmapsf': 0.125, 'filter': 'g'},
#  {'jd': 2459250.82382, 'magpsf': 19.083, 'sigmapsf': 0.116, 'filter': 'g'},
#  {'jd': 2459250.85462, 'magpsf': 18.978, 'sigmapsf': 0.124, 'filter': 'r'},
#  {'jd': 2459250.79564, 'magpsf': 19.11, 'sigmapsf': 0.117, 'filter': 'g'},
#  {'jd': 2459250.90696, 'magpsf': 19.059, 'sigmapsf': 0.147, 'filter': 'r'},
#  {'jd': 2459250.90743, 'magpsf': 19.041, 'sigmapsf': 0.127, 'filter': 'r'},
#  {'jd': 2459251.77016, 'magpsf': 19.155, 'sigmapsf': 0.108, 'filter': 'g'},
#  {'jd': 2459251.81271, 'magpsf': 19.065, 'sigmapsf': 0.105, 'filter': 'r'},
#  {'jd': 2459251.81841, 'magpsf': 19.032, 'sigmapsf': 0.102, 'filter': 'r'},
#  {'jd': 2459252.71361, 'magpsf': 18.996, 'sigmapsf': 0.137, 'filter': 'r'},
#  {'jd': 2459251.82029, 'magpsf': 19.047, 'sigmapsf': 0.107, 'filter': 'r'},
#  {'jd': 2459251.8678, 'magpsf': 19.164, 'sigmapsf': 0.109, 'filter': 'g'},
#  {'jd': 2459252.78422, 'magpsf': 19.143, 'sigmapsf': 0.102, 'filter': 'g'},
#  {'jd': 2459252.78564, 'magpsf': 19.25, 'sigmapsf': 0.123, 'filter': 'g'},
#  {'jd': 2459252.81398, 'magpsf': 19.066, 'sigmapsf': 0.119, 'filter': 'r'},
#  {'jd': 2459252.87178, 'magpsf': 18.984, 'sigmapsf': 0.1, 'filter': 'r'},
#  {'jd': 2459254.77025, 'magpsf': 19.1, 'sigmapsf': 0.1, 'filter': 'r'},
#  {'jd': 2459254.77646, 'magpsf': 19.265, 'sigmapsf': 0.095, 'filter': 'g'},
#  {'jd': 2459256.73625, 'magpsf': 19.095, 'sigmapsf': 0.095, 'filter': 'r'},
#  {'jd': 2459256.79487, 'magpsf': 19.33, 'sigmapsf': 0.105, 'filter': 'g'},
#  {'jd': 2459260.7558, 'magpsf': 19.245, 'sigmapsf': 0.192, 'filter': 'r'},
#  {'jd': 2459260.80374, 'magpsf': 19.601, 'sigmapsf': 0.159, 'filter': 'g'}]

# %% [markdown]
# ## Plot a light curve
# Define a function to plot the light curve of a given transient

# %%
oe = lc_dict["ZTF21aagnvvk"]#["sigmapsf"]
oe#["sigmapsf"]
# Out:
# [{'jd': 2459232.78481, 'magpsf': 20.856, 'sigmapsf': 0.371, 'filter': 'g'},
#  {'jd': 2459232.88103, 'magpsf': 20.705, 'sigmapsf': 0.269, 'filter': 'g'},
#  {'jd': 2459232.92484, 'magpsf': 20.591, 'sigmapsf': 0.286, 'filter': 'g'},
#  {'jd': 2459233.77119, 'magpsf': 20.487, 'sigmapsf': 0.273, 'filter': 'r'},
#  {'jd': 2459248.75645, 'magpsf': 19.06, 'sigmapsf': 0.11, 'filter': 'g'},
#  {'jd': 2459248.76622, 'magpsf': 19.032, 'sigmapsf': 0.09, 'filter': 'g'},
#  {'jd': 2459248.75551, 'magpsf': 19.082, 'sigmapsf': 0.104, 'filter': 'g'},
#  {'jd': 2459248.86705, 'magpsf': 18.948, 'sigmapsf': 0.104, 'filter': 'r'},
#  {'jd': 2459248.88325, 'magpsf': 18.924, 'sigmapsf': 0.094, 'filter': 'r'},
#  {'jd': 2459248.90036, 'magpsf': 19.016, 'sigmapsf': 0.113, 'filter': 'g'},
#  {'jd': 2459248.88231, 'magpsf': 19.025, 'sigmapsf': 0.094, 'filter': 'r'},
#  {'jd': 2459248.93757, 'magpsf': 19.023, 'sigmapsf': 0.11, 'filter': 'r'},
#  {'jd': 2459249.79897, 'magpsf': 19.158, 'sigmapsf': 0.28, 'filter': 'r'},
#  {'jd': 2459249.88734, 'magpsf': 18.997, 'sigmapsf': 0.157, 'filter': 'r'},
#  {'jd': 2459250.7448, 'magpsf': 19.049, 'sigmapsf': 0.157, 'filter': 'r'},
#  {'jd': 2459249.83978, 'magpsf': 19.016, 'sigmapsf': 0.151, 'filter': 'r'},
#  {'jd': 2459250.77574, 'magpsf': 19.082, 'sigmapsf': 0.121, 'filter': 'g'},
#  {'jd': 2459250.79469, 'magpsf': 19.041, 'sigmapsf': 0.125, 'filter': 'g'},
#  {'jd': 2459250.82382, 'magpsf': 19.083, 'sigmapsf': 0.116, 'filter': 'g'},
#  {'jd': 2459250.85462, 'magpsf': 18.978, 'sigmapsf': 0.124, 'filter': 'r'},
#  {'jd': 2459250.79564, 'magpsf': 19.11, 'sigmapsf': 0.117, 'filter': 'g'},
#  {'jd': 2459250.90696, 'magpsf': 19.059, 'sigmapsf': 0.147, 'filter': 'r'},
#  {'jd': 2459250.90743, 'magpsf': 19.041, 'sigmapsf': 0.127, 'filter': 'r'},
#  {'jd': 2459251.77016, 'magpsf': 19.155, 'sigmapsf': 0.108, 'filter': 'g'},
#  {'jd': 2459251.81271, 'magpsf': 19.065, 'sigmapsf': 0.105, 'filter': 'r'},
#  {'jd': 2459251.81841, 'magpsf': 19.032, 'sigmapsf': 0.102, 'filter': 'r'},
#  {'jd': 2459252.71361, 'magpsf': 18.996, 'sigmapsf': 0.137, 'filter': 'r'},
#  {'jd': 2459251.82029, 'magpsf': 19.047, 'sigmapsf': 0.107, 'filter': 'r'},
#  {'jd': 2459251.8678, 'magpsf': 19.164, 'sigmapsf': 0.109, 'filter': 'g'},
#  {'jd': 2459252.78422, 'magpsf': 19.143, 'sigmapsf': 0.102, 'filter': 'g'},
#  {'jd': 2459252.78564, 'magpsf': 19.25, 'sigmapsf': 0.123, 'filter': 'g'},
#  {'jd': 2459252.81398, 'magpsf': 19.066, 'sigmapsf': 0.119, 'filter': 'r'},
#  {'jd': 2459252.87178, 'magpsf': 18.984, 'sigmapsf': 0.1, 'filter': 'r'},
#  {'jd': 2459254.77025, 'magpsf': 19.1, 'sigmapsf': 0.1, 'filter': 'r'},
#  {'jd': 2459254.77646, 'magpsf': 19.265, 'sigmapsf': 0.095, 'filter': 'g'},
#  {'jd': 2459256.73625, 'magpsf': 19.095, 'sigmapsf': 0.095, 'filter': 'r'},
#  {'jd': 2459256.79487, 'magpsf': 19.33, 'sigmapsf': 0.105, 'filter': 'g'},
#  {'jd': 2459260.7558, 'magpsf': 19.245, 'sigmapsf': 0.192, 'filter': 'r'},
#  {'jd': 2459260.80374, 'magpsf': 19.601, 'sigmapsf': 0.159, 'filter': 'g'}]

# %%
def plot_lc(name):
    """
    Plot a light curve given a ZTF transient name.
    Assume lc_dict to be a global variable already defined.

    Parameters
    ----------
    name str
        name (objectId) of the ZTF transient
    """
    # Get the lc of interest
    lc = lc_dict[name]
    # What are the filters in which it was observed
    filters = [x["filter"] for x in lc]
    
    # Initialize the figure
    fig, ax = plt.subplots()
    
    # Plot the light curve in each filter
    for f in set(filters):
        time = [x["jd"] for x in lc if x['filter'] == f]
        mag = [x["magpsf"] for x in lc if x['filter'] == f]#...
        magerr = [x["sigmapsf"] for x in lc if x['filter'] == f]#...
        ax.errorbar(time, mag, yerr=magerr, marker="o", label=f)
    # Legend without repeatitions
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = OrderedDict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys())
    # Axes name
    #...
    
    # Note: smaller magnitude means larger luminosity!
    ax.set_ylim(ax.get_ylim()[::-1])
    plt.show()

# %%
# Try out the new function ZTF21aagnvvk
plot_lc("ZTF21aagnvvk")

# %% [markdown]
# Bonus quiz: Now try out the plotting function on ZTF21aagmryd. Can you guess which type of supernova this is ONLY based on the light curve?

# %%
plot_lc("ZTF21aagmryd")

# %% [markdown]
# # Fast transient quest
#
# Now the real search for fast transients begins!

# %% [markdown]
# ## Moving objects
#
# <img src="Figures/figure_asteroid.jpg" alt="drawing" width="500"/>
#
# Objects that move in the sky significantly in little time are likely asteroids or other types of natural (or artificial) near-Earth objects. Those must be removed from the sample.
#
# The ZTF alerts include valuable information such as the distance to the nearest catalogued solar system objects (`ssdistnr`). How many alerts fall within 10 arcsec from a catalog solar system object? Note: if no match is found, `ssdistnr == -999`

# %%
crit_moving = (df_alerts["ssdistnr"] < ...) & (df_alerts["ssdistnr"] > 0)
len(df_alerts[crit_moving])

# %%
# Now define a criterion to EXCLUDE those moving objects
crit_nomoving = ~crit_moving

# %% [markdown]
# This is good, but probably not enough to exclude all the moving objects. Some may be uncataloged, and others might not be precisely localized. Another effective way to remove moving objects is to set a minimum time gap between the first and the last detection of a transient. Usually, asteroids move > 1 arcsec every 15 minutes. Our target transients (kilonovae, GRB afterglows) evolve in minutes to days time scales, so we can afford to set a minimum time gap of 30 minutes, for extra safety.
#
# To build this criterion, we can use the `jd` and the `jdstarthist` keys present in every alert.

# %%
crit_mingap = (df_alerts["jd"] - ... > ...)
len(df_alerts[crit_mingap])

# %% [markdown]
# Putting the no-moving criteria together, what fraction of alerts remains?

# %%
len(df_alerts[crit_nomoving & crit_mingap])/...

# %% [markdown]
# ## Stellarity
# “Dwell on the beauty of life. Watch the stars, and see yourself running with them.” <br>
# ― Marcus Aurelius, Meditations
#
# “Dwell on the beauty of life. Watch the stars, and see yourself running away from them.” <br>
# ― Extragalactic Astronomers
#
# <img src="Figures/figure_stellarity.png" alt="drawing" width="400"/>

# %% [markdown]
# The star/galaxy classifier can help us remove stellar sources from the sample. As mentioned before, the star/galaxy classification goes from 0 (likely galaxy) to 1 (likely star). We can wonder:
# - is the location of the transient coincident with the location of a catalogued source?
# - is the closest source likely a star or a galaxy?
#
# A combination of `sgscore1` and `distpsnr1` will answer both questions. Remember that the PSF of the ZTF camera has FWHM ~ 1 arcsec and the seeing at Palomar Observatory is often 1.0-1.5 arcsec.

# %%
crit_stellar = (df_alerts["sgscore1"] > 0.5) & (df_alerts["distpsnr1"] < ...) & (df_alerts["distpsnr1"] >= 0)
crit_nostellar = ~crit_stellar

# %% [markdown]
# What fraction of alerts are likely generated by stellar sources? (Imagine what this fraction would be if we included also those sources with Galactic latitude |b| < 8 deg)

# %%
len(...)/...

# %% [markdown]
# Bonus: plot the light curve of the star with most detections among those never brighter than 17 mag in any band.

# %%
...

# %% [markdown]
# ## Total duration
# We are interested in fast transients, but what this means is somewhat ambiguous. However, if we think of electromagnetic counterparts to gravitational waves, we expect them to remain bright (for a given detection limit) for a few days, perhaps weeks but only for exceptionally nearby or bright cases.
#
# Bonus quiz: assuming that ZTF has a limitng magnitude of ~20.5 mag, how long would a GW170817-like kilonova be detectable in g and r band? What if it was located at 120 Mpc instead of 41 Mpc?

# %%
# Set a threshold for the duration
max_duration = ...
crit_maxduration = (... < max_duration)
len(df_alerts[crit_maxduration])

# %% [markdown]
# **Note:** The light curves put together for this notebook contain data points that were acquired even **after** the last alert present in the datafile. Therefore some transients pass the total duration criterion, but their light curve plot will show a long-duration transient. Building a criterion based on the light curves rather than on the alerts would yield an even better selection.

# %% [markdown]
# ## Put together the selection criteria
# How many alerts are left when the criteria for moving objects, stellarity, and duration are put together? How many transients? What is the fraction of sources that were discarded in the process?

# %%
df_alerts_select = df_alerts[crit_nomoving & ... & ... & ...]
print("Number of alerts left:", len(df_alerts_select))
print("Number of transients that pass the cuts:", ...) # remember objectId
# Discarded sources
n_tot_sources = len(set(df_alerts["objectId"]))
n_select_sources = len(set(df_alerts_select["objectId"]))
fraction_discarded = (...)/n_tot_sources
print("Fraction of discarded sources:", fraction_discarded)

# %% [markdown]
# This is very good, but is it good enough? Is this sustainable for daily scanning/vetting by humans? It is doable, but we can do better.

# %% [markdown]
# ## Light curve evolution
# We still have a powerful tool that we can use: the rate at which the luminosity changes! The alerts present in the data set were all generated in one night, so we should move to the light curve data at this point.
#
# In Python it is better to stay away from `for` loops, but since we have only a few hundreds of transients left, we can afford to iterate and analyze each light curve individually.
#
# Before doing that, we must define a function that determines whether a light curve shall pass or not pass a given criterion on its evolution. To do things properly, we should consider a rising phase (typically faster) and a fading phase (typically slower) and/or fit models to the data (see, e.g., the methods used in the [ZTFReST](https://ui.adsabs.harvard.edu/abs/2021ApJ...918...63A/abstract) framework). We can build a simplified version of this algorithm.

# %%
def evaluate_lc(name, thresh=0.3):
    """
    Evaluate if a light curve evolves fast enough
    Assume lc_dict to be a global variable already defined.

    Parameters
    ----------
    name str
        name (objectId) of the ZTF transient
    thresh float
        threshold for the evolution rate (mag/day)
    
    Returns
    -------
    selected bool
        if the transient fades faster than thresh
        in at least one band, returns True, otherwise False
    """
    # Initialize the variable to return
    selected = False
    # Individual light curve
    lc = lc_dict[name]
    # Iterate on the filters
    filters = ... # See the plot_lc function
    for f in set(filters):
        time = ...
        mag = ...
        magerr = ...
        # Condition for the rise/fade rate
        if np.abs(np.max(mag) - np.min(mag))/(time[np.argmax(mag)]-time[np.argmin(mag)]) > thresh:
            selected = True
            # No need to keep going if selected becomes True
            break
    
    return selected

# %% [markdown]
# Let's try it out. How many transients have a light curve that evolves faster than 0.5 mag/day?

# %%
names_selected = []
for name in set(df_alerts_select["objectId"]):
    try:
        if evaluate_lc(name, ...) is True:
            names_selected.append(name)
    except KeyError:
        print(f"{name} not present in light curve file, ignore")
print("Number of sources to vet:", len(names_selected))

# %%
names_selected

# %% [markdown]
# Plot the light curves and complete the candidate vetting on [Fritz](https://fritz.science). which one of the selected transients is most likely a genuine extragalactic fast transient?

# %%
plot_lc(...)

# %%
plot_lc(...)

# %% [markdown]
# # Epilogue
#
# Epilogue to be read in the `fast_transients_solutions.ipynb` notebook!
